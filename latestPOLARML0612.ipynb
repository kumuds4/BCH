# %% [markdown]
# <a href="https://colab.research.google.com/github/kumuds4/BCH/blob/master/latestPOLARML0612.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making the Most of your Colab Subscription

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Faster GPUs
#
# Users who have purchased one of Colab's paid plans have access to faster GPUs and more memory. You can upgrade your notebook's GPU settings in `Runtime > Change runtime type` in the menu to select from several accelerator options, subject to availability.
#
# The free of charge version of Colab grants access to Nvidia's T4 GPUs subject to quota restrictions and availability.
#
# You can see what GPU you've been assigned at any time by executing the following cell. If the execution result of running the code cell below is "Not connected to a GPU", you can change the runtime by going to `Runtime > Change runtime type` in the menu to enable a GPU accelerator, and then re-execute the code cell.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Jun 14 02:05:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# In order to use a GPU with your notebook, select the `Runtime > Change runtime type` menu, and then set the hardware accelerator to the desired option.

# %% [markdown]
# ## More memory
#
# Users who have purchased one of Colab's paid plans have access to high-memory VMs when they are available. More powerful GPUs are always offered with high-memory VMs.
#
#
#
# You can see how much memory you have available at any time by running the following code cell. If the execution result of running the code cell below is "Not using a high-RAM runtime", then you can enable a high-RAM runtime via `Runtime > Change runtime type` in the menu. Then select High-RAM in the Runtime shape toggle button. After, re-execute the code cell.

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# ## Longer runtimes
#
# All Colab runtimes are reset after some period of time (which is faster if the runtime isn't executing code). Colab Pro and Pro+ users have access to longer runtimes than those who use Colab free of charge.
#
# ## Background execution
#
# Colab Pro+ users have access to background execution, where notebooks will continue executing even after you've closed a browser tab. This is always enabled in Pro+ runtimes as long as you have compute units available.

# %% [markdown]
# ## Relaxing resource limits in Colab Pro
#
# Your resources are not unlimited in Colab. To make the most of Colab, avoid using resources when you don't need them. For example, only use a GPU when required and close Colab tabs when finished.
#
#
#
# If you encounter limitations, you can relax those limitations by purchasing more compute units via Pay As You Go. Anyone can purchase compute units via [Pay As You Go](https://colab.research.google.com/signup); no subscription is required.

# %% [markdown]
# ## Send us feedback!
#
# If you have any feedback for us, please let us know. The best way to send feedback is by using the Help > 'Send feedback...' menu. If you encounter usage limits in Colab Pro consider subscribing to Pro+.
#
# If you encounter errors or other issues with billing (payments) for Colab Pro, Pro+, or Pay As You Go, please email [colab-billing@google.com](mailto:colab-billing@google.com).

# %% [markdown]
# ## More Resources
#
# ### Working with Notebooks in Colab
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## Machine Learning Examples
#
# To see end-to-end examples of the interactive machine learning analyses that Colab makes possible, check out these tutorials using models from [TensorFlow Hub](https://tfhub.dev).
#
# A few featured examples:
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import logging
import pandas as pd
import traceback

import matplotlib.pyplot as plt
from matplotlib.ticker import LogFormatterMathtext
from matplotlib.ticker import LogFormatterMathtext
# Configure logging
logging.basicConfig(level=logging.INFO)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Configuration parameters
BLOCK_LENGTH = 128
INFO_BITS = 64
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 64
NUM_SAMPLES_TRAIN = 50000
NUM_SAMPLES=50000
NUM_TRIALS_PERF = 200
SNR_RANGE_AWGN = np.linspace(0, 5, 11)
#snr_range = [0, 5, 10]
LIST_SIZES = [1, 8, 16]
snr_db = 5.0     # <----- You can name this however you like!
crc_poly = [1, 0, 0, 0, 1, 0, 0, 1]
#generator = PolarCodeGenerator(N=BLOCK_LENGTH, K=INFO_BITS, crc_poly=crc_poly)
#G = PolarCodeGenerator(N=BLOCK_LENGTH, K=INFO_BITS, crc_poly=crc7_poly)
#DATASET_SNR_DB = 5.0 # Added configuration for dataset SNR


#part 2

def compute_crc(data, polynomial):
    poly_len = len(polynomial)
    crc_length = poly_len - 1
    data_with_zeros = np.concatenate((data, np.zeros(crc_length, dtype=int)))
    remainder = np.copy(data_with_zeros)
    for i in range(len(remainder) - poly_len + 1):
        if remainder[i] == 1:
            remainder[i:i + poly_len] ^= polynomial
    return remainder[-crc_length:]
###################################################################################
#Latest Polarcode generator
#Latest Polarcode generator
class PolarCodeGenerator:
    """
    Polar Code Generator for N=128 (with CRC option, reliability sequence for info/frozen placement).
    """
    # Reliability order for N=128 (first is most reliable, last is least reliable)
    RELIABILITY_SEQUENCE_128 = [
        0, 1, 2, 4, 8, 16, 3, 5, 6, 9, 10, 12, 17, 18, 20, 24,
        32, 7, 11, 13, 14, 19, 21, 22, 25, 26, 28, 33, 34, 36, 38, 40,
        15, 23, 27, 29, 30, 35, 37, 39, 41, 42, 44, 48, 31, 43, 45, 46,
        49, 50, 52, 56, 47, 51, 53, 54, 57, 58, 60, 62, 63, 55, 59, 61,
        64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79,
        80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95,
        96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109,
        110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127
    ]

    def __init__(self, N=128, K=64, crc_poly=None):
        """
        Args:
            N (int): Codeword/block length (should match length of RELIABILITY_SEQUENCE_128)
            K (int): Number of payload (info) bits (without CRC)
            crc_poly (list, optional): CRC polynomial as a binary list, e.g. [1,0,0,0,1,0,0,1] for CRC-7
        """
        self.N = N
        self.K = K
        self.crc_poly = np.array(crc_poly, dtype=int) if crc_poly is not None else None

        # Compute CRC length, total info bits, and info/frozen positions
        self.crc_length = 0 if self.crc_poly is None else (len(self.crc_poly) - 1)
        self.KwCRC = K + self.crc_length  # Total info bits (with CRC if used)

        # Ensure RELIABILITY_SEQUENCE_128 is large enough for N
        if N > len(self.RELIABILITY_SEQUENCE_128):
             raise ValueError(f"Reliability sequence only defined for N=128. Got N={N}")
        if self.KwCRC > N:
             raise ValueError(f"K + CRC length ({self.KwCRC}) cannot be greater than N ({N})")

        # Info bits are placed at the self.KwCRC most reliable positions
        self.info_set = sorted(self.RELIABILITY_SEQUENCE_128[:self.KwCRC])
        self.frozen_set = sorted(set(range(N)) - set(self.info_set))

        logging.info(f"Generator initialized: N={self.N}, K={self.K}, CRC Length={self.crc_length}, KwCRC={self.KwCRC}")
        # logging.info(f"Info set indices: {self.info_set}")
        # logging.info(f"Frozen set indices: {self.frozen_set}")


    def encode(self, payload_bits):
        """
        Args:
            payload_bits (array-like): Length K (payload, i.e. without CRC).
        Returns:
            codeword (np.array): Encoded polar codeword (length N)
            info_bits_with_crc (np.array): Full info vector (payload + CRC if used, length KwCRC)
        """
        payload_bits = np.array(payload_bits, dtype=int)
        if len(payload_bits) != self.K:
            raise ValueError(f"Expected {self.K} payload bits, got {len(payload_bits)}")

        # Add CRC bits if needed
        if self.crc_poly is not None:
            # Use the global compute_crc or define it within the class if preferred
            crc_bits = compute_crc(payload_bits, self.crc_poly)
            info_bits_with_crc = np.concatenate([payload_bits, crc_bits])
        else:
            info_bits_with_crc = payload_bits

        if len(info_bits_with_crc) != self.KwCRC:
             raise RuntimeError(f"CRC appending resulted in {len(info_bits_with_crc)} bits, expected {self.KwCRC}")


        # Place info bits at most reliable positions, rest frozen (zero)
        u = np.zeros(self.N, dtype=int)
        # Place info_bits_with_crc into the u vector at info_set indices
        u[self.info_set] = info_bits_with_crc
        codeword = self._arikan_transform(u)
        return codeword, info_bits_with_crc

    def _arikan_transform(self, u):
        """
        Fast polar (Arıkan) transform (in-place butterfly).
        """
        N = len(u)
        x = u.copy()
        n = int(np.log2(N))
        for i in range(n):
            step = 2 ** i
            for j in range(0, N, 2*step):
                for k in range(step):
                    x[j+k] ^= x[j+k+step]
        return x

    # Removed redundant compute_crc method here, using the global one


    def generate_info_bits(self):
        # Generates K information bits (payload)
        return np.random.randint(2, size=self.K)

    # Removed _place_info_bits and _polar_encode_recursive, replaced by encode method

    # Removed append_crc here, now handled inside encode method using the global compute_crc


# --- Simulation Functions ---

def bpsk_modulate(bits):
    # Map 0 -> +1, 1 -> -1
    bits = np.array(bits, dtype=int)
    return 1 - 2*bits

def add_awgn_noise(x, snr_db, code_rate):
    """
    Adds AWGN noise. SNR here is Eb/N0, bit energy to noise ratio, in dB.
    Requires code_rate (K_info / N or KwCRC / N). Using KwCRC/N for rate.
    """
    snr_linear_eb = 10**(snr_db/10)
    # Noise variance sigma^2 = N0/2.
    # Eb/N0 = (Es/R) / N0, Es=1 for BPSK
    # N0 = 1 / (R * (Eb/N0))
    # sigma^2 = 1 / (2 * R * (Eb/N0)_linear)
    noise_var = 1 / (2 * code_rate * snr_linear_eb)
    noise = np.sqrt(noise_var) * np.random.randn(*x.shape)
    return x + noise, noise_var

def make_llr(received, noise_var):
    return 2*received/noise_var

def prepare_polar_dataset(gen, num_samples, snr_db, channel_type='AWGN'):
    """
    Prepares a dataset of noisy channel outputs (LLRs) and corresponding
    original information bits (payload + CRC).
    """
    X_data = np.zeros((num_samples, gen.N))
    # Correctly use gen.KwCRC for the size of information bits + CRC
    y_data = np.zeros((num_samples, gen.KwCRC), dtype=int)

    code_rate = gen.KwCRC / gen.N # Use the correct rate including CRC

    for i in range(num_samples):
        # 1. Generate K info bits (payload)
        payload = gen.generate_info_bits()

        # 2. Encode payload (handles CRC appending and polar transform internally)
        codeword, info_bits_with_crc = gen.encode(payload)

        # 3. BPSK modulate
        x = bpsk_modulate(codeword)

        # 4. Add noise and calculate LLRs
        if channel_type == 'AWGN':
            rx, noise_var = add_awgn_noise(x, snr_db, code_rate)
            llr = make_llr(rx, noise_var)
        # Add other channel types here if needed
        else:
            raise ValueError(f"Unsupported channel type: {channel_type}")

        # Store LLRs (received signal) and the original info_bits_with_crc
        X_data[i] = llr
        y_data[i] = info_bits_with_crc # y_data should be the bits we want to decode to

    return X_data, y_data

def save_dataset_to_csv(X, y, filename='dataset.csv'):
    # X shape: (num_samples, N)
    # y shape: (num_samples, KwCRC)
    # Data to save: (num_samples, N + KwCRC)
    data = np.hstack((X, y))
    columns = [f'received_{i}' for i in range(X.shape[1])] + [f'info_bit_{j}' for j in range(y.shape[1])]
    df = pd.DataFrame(data, columns=columns)
    df.to_csv(filename, index=False)
    logging.info(f"Dataset saved to {filename}")
####################################################################################
#part 3
#Rewrite
######################################################

def bpsk_modulate(bits):
    bits = np.array(bits, dtype=int)
    # Map 0 -> -1, 1 -> +1
    return 2 * bits - 1

class EnhancedChannelSimulator:
    def __init__(self, channel_type='AWGN'):
        self.channel_type = channel_type

    def simulate(self, signal, snr_db):
        # signal is assumed to be BPSK modulated (+1 or -1)
        # Calculate noise variance based on SNR_db and signal power (which is 1 for BPSK)
        # SNR_linear = E_s / N0, where E_s = 1 for BPSK
        # Noise variance sigma^2 = N0/2.
        # SNR_linear = 1 / N0 = 1 / (2 * sigma^2)
        # sigma^2 = 1 / (2 * SNR_linear)
        # Need to consider code rate R = K/N if SNR is E_b/N0
        # E_b/N0 = (E_s/R) / N0 = (1/R) * (E_s/N0) = (1/R) * SNR_linear_Es
        # SNR_linear_Es = R * SNR_linear_Eb
        # sigma^2 = 1 / (2 * SNR_linear_Es) = 1 / (2 * R * SNR_linear_Eb)
        # The PolarCodeGenerator stores K and N, but R is needed here.
        # We need the code rate from the generator. Let's pass it or the generator object.

        # Assuming snr_db provided is E_b/N0
        # We need the code rate K/N used for the encoding. Let's assume the generator object is available or pass R.
        # For now, let's assume R is available from a generator instance or a global var if constant.
        # If we simulate *per block*, we need the specific R for that block (though N, K are fixed here).
        # Let's assume R = INFO_BITS / BLOCK_LENGTH is constant.
        R = INFO_BITS / BLOCK_LENGTH # This might need adjustment if K_crc is used for rate calc

        snr_linear_eb = 10 ** (snr_db / 10)
        # Noise variance for E_b/N0
        noise_variance = 1 / (2 * R * snr_linear_eb)
        noise_std = np.sqrt(noise_variance)
        noise = noise_std * np.random.randn(*signal.shape)
        return signal + noise


def bpsk_modulate(bits):
    # Map 0 -> +1, 1 -> -1
    bits = np.array(bits, dtype=int)
    return 1 - 2*bits

def add_awgn_noise(x, snr_db, code_rate):
    """
    Adds AWGN noise. SNR here is Eb/N0, bit energy to noise ratio, in dB.
    Requires code_rate (K_info / N or KwCRC / N). Using KwCRC/N for rate.
    """
    snr_linear_eb = 10**(snr_db/10)
    # Noise variance sigma^2 = N0/2.
    # Eb/N0 = (Es/R) / N0, Es=1 for BPSK
    # N0 = 1 / (R * (Eb/N0))
    # sigma^2 = 1 / (2 * R * (Eb/N0)_linear)
    noise_var = 1 / (2 * code_rate * snr_linear_eb)
    noise = np.sqrt(noise_var) * np.random.randn(*x.shape)
    return x + noise, noise_var

def make_llr(received, noise_var):
    return 2*received/noise_var



def prepare_polar_dataset(gen, num_samples, snr_db, channel_type='AWGN'):
    """
    Prepares a dataset of noisy channel outputs (LLRs) and corresponding
    original information bits (payload + CRC).
    """
    X_data = np.zeros((num_samples, gen.N))
    # Correctly use gen.KwCRC for the size of information bits + CRC
    y_data = np.zeros((num_samples, gen.KwCRC), dtype=int)

    code_rate = gen.KwCRC / gen.N # Use the correct rate including CRC

    for i in range(num_samples):
        # 1. Generate K info bits (payload)
        payload = gen.generate_info_bits()

        # 2. Encode payload (handles CRC appending and polar transform internally)
        codeword, info_bits_with_crc = gen.encode(payload)

        # 3. BPSK modulate
        x = bpsk_modulate(codeword)

        # 4. Add noise and calculate LLRs
        if channel_type == 'AWGN':
            rx, noise_var = add_awgn_noise(x, snr_db, code_rate)
            llr = make_llr(rx, noise_var)
        # Add other channel types here if needed
        else:
            raise ValueError(f"Unsupported channel type: {channel_type}")

        # Store LLRs (received signal) and the original info_bits_with_crc
        X_data[i] = llr
        y_data[i] = info_bits_with_crc # y_data should be the bits we want to decode to

        if num_samples > 0:  # Only bother if dataset not empty
           print(f"DEBUG SNR={snr_db}: noise_var={noise_var:.4f}, example received[0]={rx[0]:.4f}, LLR[0]={llr[0]:.4f}")

    return X_data, y_data


def save_dataset_to_csv(X, y, filename='dataset.csv'):
    # X shape: (num_samples, N)
    # y shape: (num_samples, K_info)
    # Data to save: (num_samples, N + K_info)
    data = np.hstack((X, y))
    columns = [f'received_{i}' for i in range(X.shape[1])] + [f'info_bit_{j}' for j in range(y.shape[1])]
    df = pd.DataFrame(data, columns=columns)
    df.to_csv(filename, index=False)
    logging.info(f"Dataset saved to {filename}")

############################################################################################
#latest part 4
 #----- Model -----
#latest part 4
 #----- Model -----
class EnhancedRNNDecoder(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=128, num_layers=2, dropout=0.2):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        # Dropout is applied after each LSTM (except last)
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Input: [batch, code_length], reshape to [batch, seq=1, code_length]
        x_reshaped = x.unsqueeze(1)  # [B, 1, N]
        # LSTM expects sequence, but ours is just 1 timestep with full codeword
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size, device=x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size, device=x.device)
        out, _ = self.rnn(x_reshaped, (h0, c0))   # [B, 1, H]
        out = self.fc(out[:, -1, :])              # [B, output_size]
        return self.sigmoid(out)

# ----- Trainer -----
#########################################################################################################
#add loop
crc_poly = [1,0,0,0,1,0,0,1]
BLOCK_LENGTH = 128
INFO_BITS = 64
polar_code_gen = PolarCodeGenerator(N=BLOCK_LENGTH, K=INFO_BITS, crc_poly=crc_poly)

print("Sanity check: LLR magnitudes at different SNRs")
code_rate = polar_code_gen.KwCRC / polar_code_gen.N
payload = polar_code_gen.generate_info_bits()
cw, _ = polar_code_gen.encode(payload)
x = bpsk_modulate(cw)
for snr in [0, 3, 6, 10]:
    rx, noise_var = add_awgn_noise(x, snr_db=snr, code_rate=code_rate)
    llr = make_llr(rx, noise_var)

###############################################################################################
print("KwCRC (encode):", polar_code_gen.KwCRC)
print("Encoder info set:", polar_code_gen.info_set)
print("Encoder frozen set:", polar_code_gen.frozen_set)
try:
    decoder_info_set = polar_code_gen.info_set    # Pass this into your decoder
    decoder_frozen_set = polar_code_gen.frozen_set # Pass this into your decoder (see below)
    print("Decoder info set:", decoder_info_set)
    print("Decoder frozen set:", decoder_frozen_set)
except:
    print("Decoder info_set attribute missing")

print("CRC poly (encoder):", polar_code_gen.crc_poly)
print("CRC poly (decoder):", crc_poly)
#########################################################################################################
#latest Def trainer decode on 06/12/2025
# --- Trainer ---
class DecoderTrainer:
    def __init__(self, model, learning_rate, early_stop_patience=10):
        super().__init__() # No need to call super for this class structure
        self.model = model
        self.criterion = nn.BCELoss()
        self.optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        self.early_stop_patience = early_stop_patience
        self.device = next(model.parameters()).device # Get device from model

    def train(self, train_X, train_y, val_X=None, val_y=None, epochs=50, batch_size=128, snr_min=1, snr_max=7, generator=None):
        """
        Trains the RNN decoder with dynamic noisy batch generation.

        Args:
            train_X (torch.Tensor): Training data LLRs (Initial, can be re-noised).
            train_y (torch.Tensor): Training data labels (info_bits_with_crc).
            val_X (torch.Tensor, optional): Validation data LLRs.
            val_y (torch.Tensor, optional): Validation data labels.
            epochs (int): Number of training epochs.
            batch_size (int): Batch size for training.
            snr_min (float): Minimum SNR (dB) for dynamic noise generation.
            snr_max (float): Maximum SNR (dB) for dynamic noise generation.
            generator (PolarCodeGenerator): Polar code generator instance for re-encoding.
        """
        train_losses, val_losses = [], []
        best_val_loss = float('inf')
        patience_counter = 0

        # Ensure labels are float and on the correct device
        train_y = train_y.float().to(self.device)
        if val_y is not None:
            val_y = val_y.float().to(self.device)

        # Ensure input data is on the correct device
        train_X = train_X.to(self.device)
        if val_X is not None:
             val_X = val_X.to(self.device)


        # --- Debugging LLRs (Optional - run before training) ---
        # Need generator for rate and verification
        if generator is not None and hasattr(self, 'verify_llr_calculation'):
             code_rate = generator.KwCRC / generator.N
             logging.info("--- LLR Verification Before Training ---")
             # Verify at min, max, and a point in between
             # Pass generator or its attributes if needed by verify_llr_calculation
             self.verify_llr_calculation(snr_min, code_rate, generator=generator)
             self.verify_llr_calculation(snr_max, code_rate, generator=generator)
             self.verify_llr_calculation((snr_min + snr_max) / 2.0, code_rate, generator=generator)
             logging.info("--- End LLR Verification ---")
        elif generator is None:
             logging.warning("Generator not provided. Cannot perform full LLR verification.")
        else:
             logging.warning("verify_llr_calculation method not found in DecoderTrainer.")


        for epoch in range(epochs):
            epoch_loss = 0.0

            # Shuffle training set
            indices = torch.randperm(train_X.shape[0])
            # IMPORTANT: We need the original *info_bits_with_crc* (y_batch) to re-generate noisy data.
            # So, shuffle X and y together.
            # train_X_shuffled = train_X[indices] # Not strictly needed as we regenerate X
            train_y_shuffled = train_y[indices]


            self.model.train()
            for i in range(0, len(train_X), batch_size):
                # Get batch of original info_bits_with_crc (y_batch)
                y_batch = train_y_shuffled[i:i+batch_size]
                batch_size_actual = y_batch.size(0) # Handle last batch potentially smaller

                # --- Dynamic SNR and Re-generation for each batch ---
                if generator is not None:
                    batch_snr = np.random.uniform(snr_min, snr_max)
                    code_rate = generator.KwCRC / generator.N

                    # Re-generate noisy LLRs for this batch
                    info_bits_with_crc_batch_np = y_batch.cpu().int().numpy() # Convert to numpy int bits

                    X_noisy_batch_np = np.zeros((batch_size_actual, generator.N), dtype=np.float32)

                    # This loop re-encodes and adds noise for each sample in the batch
                    # This is the correct way given the current structure.
                    for k in range(batch_size_actual):
                         # Get the info_bits_with_crc for this sample
                         info_bits_with_crc_k = info_bits_with_crc_batch_np[k]

                         # Place info_bits_with_crc into the u vector at info_set indices
                         u_vec = np.zeros(generator.N, dtype=int)
                         # Ensure info_bits_with_crc_k has the expected length
                         if len(info_bits_with_crc_k) != generator.KwCRC:
                             logging.error(f"Mismatch in info_bits_with_crc length: Expected {generator.KwCRC}, got {len(info_bits_with_crc_k)}. Skipping sample.")
                             continue # Skip this sample if data is malformed

                         try:
                             u_vec[generator.info_set] = info_bits_with_crc_k # Place info+crc bits
                             # Encode u_vec using the generator's internal transform (_arikan_transform expects 'u' vector)
                             codeword = generator._arikan_transform(u_vec) # Use internal method if public encode doesn't expose u->x
                             # BPSK modulate
                             x = bpsk_modulate(codeword) # Use global bpsk_modulate
                             # Add noise and calculate LLRs
                             rx, noise_var = add_awgn_noise(x, batch_snr, code_rate) # Use global noise functions
                             llr = make_llr(rx, noise_var) # Use global make_llr
                             X_noisy_batch_np[k] = llr
                         except Exception as e:
                             logging.error(f"Error during re-generation for sample {k}: {e}")
                             traceback.print_exc()
                             # Handle errors: e.g., log, set row to zeros, or break
                             # Setting to zero might introduce bias, but avoids crash.
                             X_noisy_batch_np[k] = np.zeros(generator.N, dtype=np.float32) # Use zeros on error


                    # Convert the re-generated batch back to a PyTorch tensor and move to device
                    X_noisy = torch.tensor(X_noisy_batch_np, dtype=torch.float32).to(self.device)

                    # --- Optional: Debugging Re-generated Batch LLRs ---
                    # if i == 0 and epoch % 10 == 0: # Debug first batch every few epochs
                    #      logging.info(f"Epoch {epoch+1}, Batch {i//batch_size + 1}: Re-generated Batch SNR: {batch_snr:.2f}")
                    #      # Add verification calls here if needed, requires getting original bits from y_batch
                    #      pass


                else:
                    # If no generator, use the original LLRs for the batch
                    logging.warning("Generator not provided. Training on static initial LLRs.")
                    # Use the batch from the shuffled initial dataset
                    X_noisy = train_X[indices[i:i+batch_size]]


                # --- Forward Pass ---
                outputs = self.model(X_noisy)
                loss = self.criterion(outputs, y_batch) # y_batch is already float

                # --- Backward Pass and Optimization ---
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
                epoch_loss += loss.item() * batch_size_actual # Accumulate weighted by actual batch size

            train_losses.append(epoch_loss / len(train_X)) # Average over total training samples

            # ----- Validation -----
            if val_X is not None and val_y is not None and generator is not None:
                self.model.eval()
                # Evaluate on validation data at a fixed SNR (e.g., median)
                val_snr = (snr_min + snr_max) / 2.0

                # Re-generate validation batch with noise at val_snr
                info_bits_with_crc_val_np = val_y.cpu().int().numpy() # Convert to numpy int bits
                X_noisy_val_batch_np = np.zeros((val_X.size(0), generator.N), dtype=np.float32)
                code_rate = generator.KwCRC / generator.N

                for k in range(val_X.size(0)):
                      info_bits_with_crc_k = info_bits_with_crc_val_np[k]
                      u_vec = np.zeros(generator.N, dtype=int)

                      if len(info_bits_with_crc_k) != generator.KwCRC:
                          logging.error(f"Validation: Mismatch in info_bits_with_crc length for sample {k}: Expected {generator.KwCRC}, got {len(info_bits_with_crc_k)}. Skipping sample.")
                          continue

                      try:
                          u_vec[generator.info_set] = info_bits_with_crc_k
                          codeword = generator._arikan_transform(u_vec) # Use internal method if public encode doesn't expose u->x
                          x = bpsk_modulate(codeword) # Use global bpsk_modulate
                          rx, noise_var = add_awgn_noise(x, val_snr, code_rate) # Use global noise functions
                          llr = make_llr(rx, noise_var) # Use global make_llr
                          X_noisy_val_batch_np[k] = llr
                      except Exception as e:
                          logging.error(f"Validation: Error during re-generation for sample {k}: {e}")
                          traceback.print_exc()
                          X_noisy_val_batch_np[k] = np.zeros(generator.N, dtype=np.float32) # Use zeros on error

                X_noisy_val = torch.tensor(X_noisy_val_batch_np, dtype=torch.float32).to(self.device)

                with torch.no_grad():
                    val_output = self.model(X_noisy_val)
                    val_loss = self.criterion(val_output, val_y).item()
                val_losses.append(val_loss)

                print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience_counter = 0
                    torch.save(self.model.state_dict(), "best_rnn_decoder.pt")
                    logging.info(f"Epoch {epoch+1}: Best validation loss improved, saving model.")
                else:
                    patience_counter += 1
                    if patience_counter >= self.early_stop_patience:
                        print(f"Early stopping activated after {self.early_stop_patience} epochs without improvement.")
                        break
            elif val_X is not None and val_y is not None and generator is None:
                 logging.warning("Generator not provided. Validation will use static initial LLRs.")
                 self.model.eval()
                 with torch.no_grad():
                     val_output = self.model(val_X)
                     val_loss = self.criterion(val_output, val_y).item()
                 val_losses.append(val_loss)
                 print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f}")
                 # Early stopping logic here would need to be based on training loss or just disabled
                 # Assuming early stopping is less useful without dynamic validation data
            else:
                # No validation set provided
                print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f}")
                # If no validation, save model based on train loss or periodically
                if len(train_losses) == 1 or train_losses[-1] < train_losses[-2]:
                     torch.save(self.model.state_dict(), "last_rnn_decoder.pt") # Save latest if improving train loss


        # Load the best model weights if early stopping occurred and validation was used
        if patience_counter >= self.early_stop_patience and val_X is not None:
             try:
                 self.model.load_state_dict(torch.load("best_rnn_decoder.pt"))
                 print("Loaded best model based on validation performance.")
             except FileNotFoundError:
                 logging.warning("Best model file not found after early stopping. Using last epoch weights.")
        elif val_X is None:
            # If no validation, you might want to load the last saved model
             try:
                 self.model.load_state_dict(torch.load("last_rnn_decoder.pt"))
                 print("Loaded last saved model (no validation used for early stopping).")
             except FileNotFoundError:
                 logging.warning("Last model file not found. Using final epoch weights.")


        return train_losses, val_losses if len(val_losses)>0 else None

    # --- Moved evaluate method INSIDE the DecoderTrainer class ---
    def evaluate(self, X_test, y_test, threshold=0.5):
        """
        Evaluates the decoder performance (BER and BLER).
        Assumes X_test is LLRs (for the codeword) and y_test are original info_bits_with_crc (labels).
        """
        self.model.eval()
        # Ensure y_test is int for comparison and on the correct device
        y_test_int = y_test.int().to(self.device) # These are the true info_bits_with_crc
        X_test = X_test.to(self.device) # These are the LLRs for the test codewords

        with torch.no_grad():
            outputs = self.model(X_test) # Model predicts KwCRC bits (probabilities)

            # Threshold probabilities to get hard bit predictions for KwCRC bits
            preds_kwcrc = (outputs > threshold).int() # Predicted info_bits_with_crc

            # --- Calculate BER ---
            total_bits_kwcrc = y_test_int.numel()
            bit_errors_kwcrc = torch.sum(preds_kwcrc != y_test_int).item()
            ber_kwcrc = bit_errors_kwcrc / total_bits_kwcrc if total_bits_kwcrc > 0 else 0.0

            # --- Calculate BLER ---
            block_error_flags_kwcrc = torch.any(preds_kwcrc != y_test_int, dim=1)
            block_errors_kwcrc = torch.sum(block_error_flags_kwcrc).item()
            total_blocks = X_test.size(0)
            bler_kwcrc = block_errors_kwcrc / total_blocks if total_blocks > 0 else 0.0

        # Return ONLY two values (BER, BLER) for the KwCRC bits
        return ber_kwcrc, bler_kwcrc

    # --- Moved verify_llr_calculation method INSIDE the DecoderTrainer class ---
    def verify_llr_calculation(self, snr_db, code_rate, num_samples=10000, generator=None):
        """Generates random bits, encodes, adds noise, calculates LLRs,
           and compares with expected LLR behavior. Requires generator."""
        if generator is None:
            logging.warning("Cannot verify LLR calculation without a generator.")
            return

        logging.info(f"Verifying LLR calculation for SNR={snr_db} dB, Rate={code_rate}")

        # Generate random bits (equivalent of info_bits_with_crc for this test)
        # We need N bits to simulate the codeword for LLR verification purposes
        # This is a simplified test - real LLRs are on channel output of codeword
        # A better verification would encode random payload bits using the generator
        # and then check LLRs of the *encoded* codeword.
        # For this simplified check, let's generate N random bits and treat them as BPSK symbols
        random_bits_for_bpsk = np.random.randint(2, size=(num_samples, generator.N))

        # Simulate channel using global functions
        # BPSK map 0->+1, 1->-1 for AWGN LLR formula derivation (as per bpsk_modulate function)
        bpsk_signal = bpsk_modulate(random_bits_for_bpsk) # Use the global bpsk_modulate
        rx_signal, noise_var = add_awgn_noise(bpsk_signal, snr_db, code_rate) # Use global add_awgn_noise
        calculated_llr = make_llr(rx_signal, noise_var) # Use global make_llr

        # Expected LLR for transmitted bit 0 (+1 in BPSK) should be positive
        # Expected LLR for transmitted bit 1 (-1 in BPSK) should be negative
        # The sign of the LLR should match the sign of the *transmitted* BPSK symbol (1 for 0, -1 for 1)
        expected_llr_signs = np.sign(1 - 2 * random_bits_for_bpsk)
        actual_llr_signs = np.sign(calculated_llr)

        # Check proportion of correct signs
        correct_sign_proportion = np.mean(expected_llr_signs == actual_llr_signs)
        logging.info(f"  Proportion of LLRs with correct sign: {correct_sign_proportion:.4f}")

        # Check mean absolute LLR magnitude (rough check)
        mean_abs_llr = np.mean(np.abs(calculated_llr))
        logging.info(f"  Mean absolute LLR magnitude: {mean_abs_llr:.4f}")

        # Example: Mean LLR for transmitted 0s vs 1s
        mean_llr_zeros = np.mean(calculated_llr[random_bits_for_bpsk == 0]) if np.any(random_bits_for_bpsk == 0) else np.nan
        mean_llr_ones = np.mean(calculated_llr[random_bits_for_bpsk == 1]) if np.any(random_bits_for_bpsk == 1) else np.nan
        logging.info(f"  Mean LLR for transmitted 0s: {mean_llr_zeros:.4f}")
        logging.info(f"  Mean LLR for transmitted 1s: {mean_llr_ones:.4f}")

        if not (np.isnan(mean_llr_zeros) or mean_llr_zeros > 0):
             logging.warning(f"  Warning: Mean LLR for transmitted 0s is not positive ({mean_llr_zeros:.4f}).")
        if not (np.isnan(mean_llr_ones) or mean_llr_ones < 0):
             logging.warning(f"  Warning: Mean LLR for transmitted 1s is not negative ({mean_llr_ones:.4f}).")

# The rest of the code (performance_comparison, plotting, main) remains the same.
# Ensure the global functions bpsk_modulate, add_awgn_noise, make_llr are defined before DecoderTrainer.
# Also ensure PolarCodeGenerator is defined and an instance polar_code_gen exists before DecoderTrainer.

#######################################################################################################











# Part 5
############################################################################
#R#################


# --- Simulation Functions ---

def bpsk_modulate(bits):
    # Map 0 -> +1, 1 -> -1
    bits = np.array(bits, dtype=int)
    return 1 - 2*bits

def add_awgn_noise(x, snr_db, code_rate):
    """
    Adds AWGN noise. SNR here is Eb/N0, bit energy to noise ratio, in dB.
    Requires code_rate (K_info / N or KwCRC / N). Using KwCRC/N for rate.
    """
    snr_linear_eb = 10**(snr_db/10)
    # Noise variance sigma^2 = N0/2.
    # Eb/N0 = (Es/R) / N0, Es=1 for BPSK
    # N0 = 1 / (R * (Eb/N0))
    # sigma^2 = 1 / (2 * R * (Eb/N0)_linear)
    noise_var = 1 / (2 * code_rate * snr_linear_eb)
    noise = np.sqrt(noise_var) * np.random.randn(*x.shape)
    return x + noise, noise_var

def make_llr(received, noise_var):
    return 2*received/noise_var

def prepare_polar_dataset(gen, num_samples, snr_db, channel_type='AWGN'):
    """
    Prepares a dataset of noisy channel outputs (LLRs) and corresponding
    original information bits (payload + CRC).
    """
    X_data = np.zeros((num_samples, gen.N))
    # Correctly use gen.KwCRC for the size of information bits + CRC
    y_data = np.zeros((num_samples, gen.KwCRC), dtype=int)

    code_rate = gen.KwCRC / gen.N # Use the correct rate including CRC

    for i in range(num_samples):
        # 1. Generate K info bits (payload)
        payload = gen.generate_info_bits()

        # 2. Encode payload (handles CRC appending and polar transform internally)
        codeword, info_bits_with_crc = gen.encode(payload)

        # 3. BPSK modulate
        x = bpsk_modulate(codeword)

        # 4. Add noise and calculate LLRs
        if channel_type == 'AWGN':
            rx, noise_var = add_awgn_noise(x, snr_db, code_rate)
            llr = make_llr(rx, noise_var)
        # Add other channel types here if needed
        else:
            raise ValueError(f"Unsupported channel type: {channel_type}")

        # Store LLRs (received signal) and the original info_bits_with_crc
        X_data[i] = llr
        y_data[i] = info_bits_with_crc # y_data should be the bits we want to decode to

    return X_data, y_data

def save_dataset_to_csv(X, y, filename='dataset.csv'):
    # X shape: (num_samples, N)
    # y shape: (num_samples, KwCRC)
    # Data to save: (num_samples, N + KwCRC)
    data = np.hstack((X, y))
    columns = [f'received_{i}' for i in range(X.shape[1])] + [f'info_bit_{j}' for j in range(y.shape[1])]
    df = pd.DataFrame(data, columns=columns)
    df.to_csv(filename, index=False)
    logging.info(f"Dataset saved to {filename}")
############################################################################################
#part 3
#Rewrite
######################################################

def bpsk_modulate(bits):
    bits = np.array(bits, dtype=int)
    # Map 0 -> -1, 1 -> +1
    return 2 * bits - 1

class EnhancedChannelSimulator:
    def __init__(self, channel_type='AWGN'):
        self.channel_type = channel_type

    def simulate(self, signal, snr_db):
        # signal is assumed to be BPSK modulated (+1 or -1)
        # Calculate noise variance based on SNR_db and signal power (which is 1 for BPSK)
        # SNR_linear = E_s / N0, where E_s = 1 for BPSK
        # Noise variance sigma^2 = N0/2.
        # SNR_linear = 1 / N0 = 1 / (2 * sigma^2)
        # sigma^2 = 1 / (2 * SNR_linear)
        # Need to consider code rate R = K/N if SNR is E_b/N0
        # E_b/N0 = (E_s/R) / N0 = (1/R) * (E_s/N0) = (1/R) * SNR_linear_Es
        # SNR_linear_Es = R * SNR_linear_Eb
        # sigma^2 = 1 / (2 * SNR_linear_Es) = 1 / (2 * R * SNR_linear_Eb)
        # The PolarCodeGenerator stores K and N, but R is needed here.
        # We need the code rate from the generator. Let's pass it or the generator object.

        # Assuming snr_db provided is E_b/N0
        # We need the code rate K/N used for the encoding. Let's assume the generator object is available or pass R.
        # For now, let's assume R = INFO_BITS / BLOCK_LENGTH is constant.
        R = INFO_BITS / BLOCK_LENGTH # This might need adjustment if K_crc is used for rate calc

        snr_linear_eb = 10 ** (snr_db / 10)
        # Noise variance for E_b/N0
        noise_variance = 1 / (2 * R * snr_linear_eb)
        noise_std = np.sqrt(noise_variance)
        noise = noise_std * np.random.randn(*signal.shape)
        return signal + noise


def bpsk_modulate(bits):
    # Map 0 -> +1, 1 -> -1
    bits = np.array(bits, dtype=int)
    return 1 - 2*bits

def add_awgn_noise(x, snr_db, code_rate):
    """
    Adds AWGN noise. SNR here is Eb/N0, bit energy to noise ratio, in dB.
    Requires code_rate (K_info / N or KwCRC / N). Using KwCRC/N for rate.
    """
    snr_linear_eb = 10**(snr_db/10)
    # Noise variance sigma^2 = N0/2.
    # Eb/N0 = (Es/R) / N0, Es=1 for BPSK
    # N0 = 1 / (R * (Eb/N0))
    # sigma^2 = 1 / (2 * R * (Eb/N0)_linear)
    noise_var = 1 / (2 * code_rate * snr_linear_eb)
    noise = np.sqrt(noise_var) * np.random.randn(*x.shape)
    return x + noise, noise_var

def make_llr(received, noise_var):
    return 2*received/noise_var



def prepare_polar_dataset(gen, num_samples, snr_db, channel_type='AWGN'):
    """
    Prepares a dataset of noisy channel outputs (LLRs) and corresponding
    original information bits (payload + CRC).
    """
    X_data = np.zeros((num_samples, gen.N))
    # Correctly use gen.KwCRC for the size of information bits + CRC
    y_data = np.zeros((num_samples, gen.KwCRC), dtype=int)

    code_rate = gen.KwCRC / gen.N # Use the correct rate including CRC

    for i in range(num_samples):
        # 1. Generate K info bits (payload)
        payload = gen.generate_info_bits()

        # 2. Encode payload (handles CRC appending and polar transform internally)
        codeword, info_bits_with_crc = gen.encode(payload)

        # 3. BPSK modulate
        x = bpsk_modulate(codeword)

        # 4. Add noise and calculate LLRs
        if channel_type == 'AWGN':
            rx, noise_var = add_awgn_noise(x, snr_db, code_rate)
            llr = make_llr(rx, noise_var)
        # Add other channel types here if needed
        else:
            raise ValueError(f"Unsupported channel type: {channel_type}")

        # Store LLRs (received signal) and the original info_bits_with_crc
        X_data[i] = llr
        y_data[i] = info_bits_with_crc # y_data should be the bits we want to decode to

        if num_samples > 0:  # Only bother if dataset not empty
           print(f"DEBUG SNR={snr_db}: noise_var={noise_var:.4f}, example received[0]={rx[0]:.4f}, LLR[0]={llr[0]:.4f}")

    return X_data, y_data


def save_dataset_to_csv(X, y, filename='dataset.csv'):
    # X shape: (num_samples, N)
    # y shape: (num_samples, K_info)
    # Data to save: (num_samples, N + K_info)
    data = np.hstack((X, y))
    columns = [f'received_{i}' for i in range(X.shape[1])] + [f'info_bit_{j}' for j in range(y.shape[1])]
    df = pd.DataFrame(data, columns=columns)
    df.to_csv(filename, index=False)
    logging.info(f"Dataset saved to {filename}")

############################################################################################
#latest part 4
 #----- Model -----
#latest part 4
 #----- Model -----
class EnhancedRNNDecoder(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=128, num_layers=2, dropout=0.2):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        # Dropout is applied after each LSTM (except last)
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Input: [batch, code_length], reshape to [batch, seq=1, code_length]
        x_reshaped = x.unsqueeze(1)  # [B, 1, N]
        # LSTM expects sequence, but ours is just 1 timestep with full codeword
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size, device=x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size, device=x.device)
        out, _ = self.rnn(x_reshaped, (h0, c0))   # [B, 1, H]
        out = self.fc(out[:, -1, :])              # [B, output_size]
        return self.sigmoid(out)

# ----- Trainer -----
#########################################################################################################
#add loop
crc_poly = [1,0,0,0,1,0,0,1]
BLOCK_LENGTH = 128
INFO_BITS = 64
polar_code_gen = PolarCodeGenerator(N=BLOCK_LENGTH, K=INFO_BITS, crc_poly=crc_poly)

print("Sanity check: LLR magnitudes at different SNRs")
code_rate = polar_code_gen.KwCRC / polar_code_gen.N
payload = polar_code_gen.generate_info_bits()
cw, _ = polar_code_gen.encode(payload)
x = bpsk_modulate(cw)
for snr in [0, 3, 6, 10]:
    rx, noise_var = add_awgn_noise(x, snr_db=snr, code_rate=code_rate)
    llr = make_llr(rx, noise_var)

###############################################################################################
print("KwCRC (encode):", polar_code_gen.KwCRC)
print("Encoder info set:", polar_code_gen.info_set)
print("Encoder frozen set:", polar_code_gen.frozen_set)
try:
    decoder_info_set = polar_code_gen.info_set    # Pass this into your decoder
    decoder_frozen_set = polar_code_gen.frozen_set # Pass this into your decoder (see below)
    print("Decoder info set:", decoder_info_set)
    print("Decoder frozen set:", decoder_frozen_set)
except:
    print("Decoder info_set attribute missing")

print("CRC poly (encoder):", polar_code_gen.crc_poly)
print("CRC poly (decoder):", crc_poly)
#########################################################################################################
#latest Def trainer decode on 06/12/2025
# --- Trainer ---
class DecoderTrainer:
    def __init__(self, model, learning_rate, early_stop_patience=10):
        # No need to call super for this class structure
        self.model = model
        self.criterion = nn.BCELoss()
        self.optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        self.early_stop_patience = early_stop_patience
        self.device = next(model.parameters()).device # Get device from model

    def train(self, train_X, train_y, val_X=None, val_y=None, epochs=50, batch_size=128, snr_min=1, snr_max=7, generator=None):
        """
        Trains the RNN decoder with dynamic noisy batch generation.

        Args:
            train_X (torch.Tensor): Training data LLRs (Initial, can be re-noised).
            train_y (torch.Tensor): Training data labels (info_bits_with_crc).
            val_X (torch.Tensor, optional): Validation data LLRs.
            val_y (torch.Tensor, optional): Validation data labels.
            epochs (int): Number of training epochs.
            batch_size (int): Batch size for training.
            snr_min (float): Minimum SNR (dB) for dynamic noise generation.
            snr_max (float): Maximum SNR (dB) for dynamic noise generation.
            generator (PolarCodeGenerator): Polar code generator instance for re-encoding.
        """
        train_losses, val_losses = [], []
        best_val_loss = float('inf')
        patience_counter = 0

        # Ensure labels are float and on the correct device
        train_y = train_y.float().to(self.device)
        if val_y is not None:
            val_y = val_y.float().to(self.device)

        # Ensure input data is on the correct device
        train_X = train_X.to(self.device)
        if val_X is not None:
             val_X = val_X.to(self.device)


        # --- Debugging LLRs (Optional - run before training) ---
        # Need generator for rate and verification
        if generator is not None and hasattr(self, 'verify_llr_calculation'):
             code_rate = generator.KwCRC / generator.N
             logging.info("--- LLR Verification Before Training ---")
             # Verify at min, max, and a point in between
             # Pass generator or its attributes if needed by verify_llr_calculation
             self.verify_llr_calculation(snr_min, code_rate, generator=generator)
             self.verify_llr_calculation(snr_max, code_rate, generator=generator)
             self.verify_llr_calculation((snr_min + snr_max) / 2.0, code_rate, generator=generator)
             logging.info("--- End LLR Verification ---")
        elif generator is None:
             logging.warning("Generator not provided. Cannot perform full LLR verification.")
        else:
             logging.warning("verify_llr_calculation method not found in DecoderTrainer.")


        for epoch in range(epochs):
            epoch_loss = 0.0

            # Shuffle training set
            indices = torch.randperm(train_X.shape[0])
            # IMPORTANT: We need the original *info_bits_with_crc* (y_batch) to re-generate noisy data.
            # So, shuffle X and y together.
            # train_X_shuffled = train_X[indices] # Not strictly needed as we regenerate X
            train_y_shuffled = train_y[indices]


            self.model.train()
            for i in range(0, len(train_X), batch_size):
                # Get batch of original info_bits_with_crc (y_batch)
                y_batch = train_y_shuffled[i:i+batch_size]
                batch_size_actual = y_batch.size(0) # Handle last batch potentially smaller

                # --- Dynamic SNR and Re-generation for each batch ---
                if generator is not None:
                    batch_snr = np.random.uniform(snr_min, snr_max)
                    code_rate = generator.KwCRC / generator.N

                    # Re-generate noisy LLRs for this batch
                    info_bits_with_crc_batch_np = y_batch.cpu().int().numpy() # Convert to numpy int bits

                    X_noisy_batch_np = np.zeros((batch_size_actual, generator.N), dtype=np.float32)

                    # This loop re-encodes and adds noise for each sample in the batch
                    # This is the correct way given the current structure.
                    for k in range(batch_size_actual):
                         # Get the info_bits_with_crc for this sample
                         info_bits_with_crc_k = info_bits_with_crc_batch_np[k]

                         # Place info_bits_with_crc into the u vector at info_set indices
                         u_vec = np.zeros(generator.N, dtype=int)
                         # Ensure info_bits_with_crc_k has the expected length
                         if len(info_bits_with_crc_k) != generator.KwCRC:
                             logging.error(f"Mismatch in info_bits_with_crc length: Expected {generator.KwCRC}, got {len(info_bits_with_crc_k)}. Skipping sample.")
                             continue # Skip this sample if data is malformed

                         try:
                             u_vec[generator.info_set] = info_bits_with_crc_k # Place info+crc bits
                             # Encode u_vec using the generator's internal transform (_arikan_transform expects 'u' vector)
                             codeword = generator._arikan_transform(u_vec) # Use internal method if public encode doesn't expose u->x
                             # BPSK modulate
                             x = bpsk_modulate(codeword) # Use global bpsk_modulate
                             # Add noise and calculate LLRs
                             rx, noise_var = add_awgn_noise(x, batch_snr, code_rate) # Use global noise functions
                             llr = make_llr(rx, noise_var) # Use global make_llr
                             X_noisy_batch_np[k] = llr
                         except Exception as e:
                             logging.error(f"Error during re-generation for sample {k}: {e}")
                             traceback.print_exc()
                             # Handle errors: e.g., log, set row to zeros, or break
                             # Setting to zero might introduce bias, but avoids crash.
                             X_noisy_batch_np[k] = np.zeros(generator.N, dtype=np.float32) # Use zeros on error


                    # Convert the re-generated batch back to a PyTorch tensor and move to device
                    X_noisy = torch.tensor(X_noisy_batch_np, dtype=torch.float32).to(self.device)

                    # --- Optional: Debugging Re-generated Batch LLRs ---
                    # if i == 0 and epoch % 10 == 0: # Debug first batch every few epochs
                    #      logging.info(f"Epoch {epoch+1}, Batch {i//batch_size + 1}: Re-generated Batch SNR: {batch_snr:.2f}")
                    #      # Add verification calls here if needed, requires getting original bits from y_batch
                    #      pass


                else:
                    # If no generator, use the original LLRs for the batch
                    logging.warning("Generator not provided. Training on static initial LLRs.")
                    # Use the batch from the shuffled initial dataset
                    X_noisy = train_X[indices[i:i+batch_size]]


                # --- Forward Pass ---
                outputs = self.model(X_noisy)
                loss = self.criterion(outputs, y_batch) # y_batch is already float

                # --- Backward Pass and Optimization ---
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
                epoch_loss += loss.item() * batch_size_actual # Accumulate weighted by actual batch size

            train_losses.append(epoch_loss / len(train_X)) # Average over total training samples

            # ----- Validation -----
            if val_X is not None and val_y is not None and generator is not None:
                self.model.eval()
                # Evaluate on validation data at a fixed SNR (e.g., median)
                val_snr = (snr_min + snr_max) / 2.0

                # Re-generate validation batch with noise at val_snr
                info_bits_with_crc_val_np = val_y.cpu().int().numpy() # Convert to numpy int bits
                X_noisy_val_batch_np = np.zeros((val_X.size(0), generator.N), dtype=np.float32)
                code_rate = generator.KwCRC / generator.N

                for k in range(val_X.size(0)):
                      info_bits_with_crc_k = info_bits_with_crc_val_np[k]
                      u_vec = np.zeros(generator.N, dtype=int)

                      if len(info_bits_with_crc_k) != generator.KwCRC:
                          logging.error(f"Validation: Mismatch in info_bits_with_crc length for sample {k}: Expected {generator.KwCRC}, got {len(info_bits_with_crc_k)}. Skipping sample.")
                          continue

                      try:
                          u_vec[generator.info_set] = info_bits_with_crc_k
                          codeword = generator._arikan_transform(u_vec) # Use internal method if public encode doesn't expose u->x
                          x = bpsk_modulate(codeword) # Use global bpsk_modulate
                          rx, noise_var = add_awgn_noise(x, val_snr, code_rate) # Use global noise functions
                          llr = make_llr(rx, noise_var) # Use global make_llr
                          X_noisy_val_batch_np[k] = llr
                      except Exception as e:
                          logging.error(f"Validation: Error during re-generation for sample {k}: {e}")
                          traceback.print_exc()
                          X_noisy_val_batch_np[k] = np.zeros(generator.N, dtype=np.float32) # Use zeros on error

                X_noisy_val = torch.tensor(X_noisy_val_batch_np, dtype=torch.float32).to(self.device)

                with torch.no_grad():
                    val_output = self.model(X_noisy_val)
                    val_loss = self.criterion(val_output, val_y).item()
                val_losses.append(val_loss)

                print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f}")

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience_counter = 0
                    torch.save(self.model.state_dict(), "best_rnn_decoder.pt")
                    logging.info(f"Epoch {epoch+1}: Best validation loss improved, saving model.")
                else:
                    patience_counter += 1
                    if patience_counter >= self.early_stop_patience:
                        print(f"Early stopping activated after {self.early_stop_patience} epochs without improvement.")
                        break
            elif val_X is not None and val_y is not None and generator is None:
                 logging.warning("Generator not provided. Validation will use static initial LLRs.")
                 self.model.eval()
                 with torch.no_grad():
                     val_output = self.model(val_X)
                     val_loss = self.criterion(val_output, val_y).item()
                 val_losses.append(val_loss)
                 print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f}")
                 # Early stopping logic here would need to be based on training loss or just disabled
                 # Assuming early stopping is less useful without dynamic validation data
            else:
                # No validation set provided
                print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f}")
                # If no validation, save model based on train loss or periodically
                if len(train_losses) == 1 or train_losses[-1] < train_losses[-2]:
                     torch.save(self.model.state_dict(), "last_rnn_decoder.pt") # Save latest if improving train loss


        # Load the best model weights if early stopping occurred and validation was used
        if patience_counter >= self.early_stop_patience and val_X is not None:
             try:
                 self.model.load_state_dict(torch.load("best_rnn_decoder.pt"))
                 print("Loaded best model based on validation performance.")
             except FileNotFoundError:
                 logging.warning("Best model file not found after early stopping. Using last epoch weights.")
        elif val_X is None:
            # If no validation, you might want to load the last saved model
             try:
                 self.model.load_state_dict(torch.load("last_rnn_decoder.pt"))
                 print("Loaded last saved model (no validation used for early stopping).")
             except FileNotFoundError:
                 logging.warning("Last model file not found. Using final epoch weights.")


        return train_losses, val_losses if len(val_losses)>0 else None

    # --- Moved evaluate method INSIDE the DecoderTrainer class ---
    def evaluate(self, X_test, y_test, threshold=0.5):
        """
        Evaluates the decoder performance (BER and BLER).
        Assumes X_test is LLRs (for the codeword) and y_test are original info_bits_with_crc (labels).
        """
        self.model.eval()
        # Ensure y_test is int for comparison and on the correct device
        y_test_int = y_test.int().to(self.device) # These are the true info_bits_with_crc
        X_test = X_test.to(self.device) # These are the LLRs for the test codewords

        with torch.no_grad():
            outputs = self.model(X_test) # Model predicts KwCRC bits (probabilities)

            # Threshold probabilities to get hard bit predictions for KwCRC bits
            preds_kwcrc = (outputs > threshold).int() # Predicted info_bits_with_crc

            # --- Calculate BER ---
            total_bits_kwcrc = y_test_int.numel()
            bit_errors_kwcrc = torch.sum(preds_kwcrc != y_test_int).item()
            ber_kwcrc = bit_errors_kwcrc / total_bits_kwcrc if total_bits_kwcrc > 0 else 0.0

            # --- Calculate BLER ---
            block_error_flags_kwcrc = torch.any(preds_kwcrc != y_test_int, dim=1)
            block_errors_kwcrc = torch.sum(block_error_flags_kwcrc).item()
            total_blocks = X_test.size(0)
            bler_kwcrc = block_errors_kwcrc / total_blocks if total_blocks > 0 else 0.0

        # Return ONLY two values (BER, BLER) for the KwCRC bits
        return ber_kwcrc, bler_kwcrc

    # --- Moved verify_llr_calculation method INSIDE the DecoderTrainer class ---
    def verify_llr_calculation(self, snr_db, code_rate, num_samples=10000, generator=None):
        """Generates random bits, encodes, adds noise, calculates LLRs,
           and compares with expected LLR behavior. Requires generator."""
        if generator is None:
            logging.warning("Cannot verify LLR calculation without a generator.")
            return

        logging.info(f"Verifying LLR calculation for SNR={snr_db} dB, Rate={code_rate}")

        # Generate random bits (equivalent of info_bits_with_crc for this test)
        # We need N bits to simulate the codeword for LLR verification purposes
        # This is a simplified test - real LLRs are on channel output of codeword
        # A better verification would encode random payload bits using the generator
        # and then check LLRs of the *encoded* codeword.
        # For this simplified check, let's generate N random bits and treat them as BPSK symbols
        random_bits_for_bpsk = np.random.randint(2, size=(num_samples, generator.N))

        # Simulate channel using global functions
        # BPSK map 0->+1, 1->-1 for AWGN LLR formula derivation (as per bpsk_modulate function)
        bpsk_signal = bpsk_modulate(random_bits_for_bpsk) # Use the global bpsk_modulate
        rx_signal, noise_var = add_awgn_noise(bpsk_signal, snr_db, code_rate) # Use global add_awgn_noise
        calculated_llr = make_llr(rx_signal, noise_var) # Use global make_llr

        # Expected LLR for transmitted bit 0 (+1 in BPSK) should be positive
        # Expected LLR for transmitted bit 1 (-1 in BPSK) should be negative
        # The sign of the LLR should match the sign of the *transmitted* BPSK symbol (1 for 0, -1 for 1)
        expected_llr_signs = np.sign(1 - 2 * random_bits_for_bpsk)
        actual_llr_signs = np.sign(calculated_llr)

        # Check proportion of correct signs
        correct_sign_proportion = np.mean(expected_llr_signs == actual_llr_signs)
        logging.info(f"  Proportion of LLRs with correct sign: {correct_sign_proportion:.4f}")

        # Check mean absolute LLR magnitude (rough check)
        mean_abs_llr = np.mean(np.abs(calculated_llr))
        logging.info(f"  Mean absolute LLR magnitude: {mean_abs_llr:.4f}")

        # Example: Mean LLR for transmitted 0s vs 1s
        mean_llr_zeros = np.mean(calculated_llr[random_bits_for_bpsk == 0]) if np.any(random_bits_for_bpsk == 0) else np.nan
        mean_llr_ones = np.mean(calculated_llr[random_bits_for_bpsk == 1]) if np.any(random_bits_for_bpsk == 1) else np.nan
        logging.info(f"  Mean LLR for transmitted 0s: {mean_llr_zeros:.4f}")
        logging.info(f"  Mean LLR for transmitted 1s: {mean_llr_ones:.4f}")

        if not (np.isnan(mean_llr_zeros) or mean_llr_zeros > 0):
             logging.warning(f"  Warning: Mean LLR for transmitted 0s is not positive ({mean_llr_zeros:.4f}).")
        if not (np.isnan(mean_llr_ones) or mean_llr_ones < 0):
             logging.warning(f"  Warning: Mean LLR for transmitted 1s is not negative ({mean_llr_ones:.4f}).")

# The rest of the code (performance_comparison, plotting, main) remains the same.
# Ensure the global functions bpsk_modulate, add_awgn_noise, make_llr are defined before DecoderTrainer.
# Also ensure PolarCodeGenerator is defined and an instance polar_code_gen exists before DecoderTrainer.

#######################################################################################################








 ############################################################################################
# --- Example Usage (Assuming other parts of your notebook are run) ---

# Assuming you have a PolarCodeGenerator instance, e.g.:
# crc7_poly = [1, 0, 0, 0, 1, 0, 0, 1] # Example CRC-7
# generator = PolarCodeGenerator(N=BLOCK_LENGTH, K=INFO_BITS, crc_poly=crc7_poly)

# Assuming you have generated initial training and validation data:
# # Define a fixed SNR for initial dataset generation
# DATASET_SNR_DB = 5.0 # You can choose an appropriate SNR
# num_train_samples = 10000
# num_val_samples = 2000 # Optional validation set

# train_X_np, train_y_np = prepare_polar_dataset(generator, num_train_samples, DATASET_SNR_DB)
# train_X = torch.FloatTensor(train_X_np)
# train_y = torch.FloatTensor(train_y_np) # Keep labels as float for training

# If using validation:
# val_X_np, val_y_np = prepare_polar_dataset(generator, num_val_samples, DATASET_SNR_DB)
# val_X = torch.FloatTensor(val_X_np)
# val_y = torch.FloatTensor(val_y_np)

# Assuming you have initialized the RNN model:
# input_size = generator.N # LLRs length
# output_size = generator.KwCRC # Info bits + CRC length
# rnn_decoder = EnhancedRNNDecoder(input_size, output_size).to(device)

# Initialize the Trainer:
# learning_rate = 1e-3
# trainer = DecoderTrainer(rnn_decoder, learning_rate=learning_rate, early_stop_patience=10)

# Start Training:
# snr_train_min = 1 # Min SNR for dynamic training noise
# snr_train_max = 7 # Max SNR for dynamic training noise

# train_losses, val_losses = trainer.train(
#     train_X, train_y,
#     val_X=val_X, val_y=val_y, # Pass validation data if available
#     epochs=EPOCHS,
#     batch_size=BATCH_SIZE,
#     snr_min=snr_train_min,
#     snr_max=snr_train_max,
#     generator=generator # Pass the


# Part 5

#######################################################################
#Rewrite Polar Code Decoder
class PolarCodeDecoder:
    """
    Polar Code Decoder supporting SC and SCL decoding, with optional CRC.
    """

    def __init__(self, N, K, list_size=1, crc_poly=None, info_set=None, frozen_set=None):
        self.N = N
        self.K = K
        self.list_size = list_size
        self.crc_poly = crc_poly
        self.crc_length = len(crc_poly) - 1 if crc_poly else 0

        # Info and frozen sets
        if info_set is not None and frozen_set is not None:
            self.info_set = list(info_set)
            self.frozen_set = list(frozen_set)
        else:
            self.frozen_set = set(range(K, N))
            self.info_set = sorted(set(range(N)) - self.frozen_set)

        # CRC failure print limit
        self.crc_fail_count = 0

    def compute_crc(self, bits, poly):
        """Compute CRC bits using modulo-2 division."""
        bits = list(bits) + [0] * (len(poly) - 1)
        for i in range(len(bits) - len(poly) + 1):
            if bits[i] == 1:
                for j in range(len(poly)):
                    bits[i + j] ^= poly[j]
        return bits[-(len(poly) - 1):]

    def crc_check(self, info_bits):
        """Check CRC correctness."""
        payload = info_bits[:-(self.crc_length)]
        crc = info_bits[-(self.crc_length):]
        computed_crc = self.compute_crc(payload, self.crc_poly)
        return np.array_equal(crc, computed_crc)

    def encode_with_crc(self, payload_bits):
        """Attach CRC to payload_bits if CRC polynomial is specified."""
        payload_bits = np.array(payload_bits, dtype=int)
        if self.crc_poly:
            crc_bits = self.compute_crc(payload_bits, self.crc_poly)
            return np.concatenate([payload_bits, crc_bits])
        return payload_bits

    def decode(self, llr):
        """Wrapper to choose SC or SCL decoding."""
        if self.list_size == 1:
            u_hat = self._sc_decode(llr)
            info_bits = u_hat[list(self.info_set)]
            if self.crc_poly and not self.crc_check(info_bits):
                self.crc_fail_count += 1
                if self.crc_fail_count <= 10:
                    print("CRC failed in SC!")
                elif self.crc_fail_count == 11:
                    print("... too many CRC failures, suppressing further output.")
            return info_bits
        else:
            return self._scl_decode(llr)

    def _sc_decode(self, llr):
        """Basic Successive Cancellation decoding."""
        u_hat = np.zeros(self.N, dtype=int)
        for i in range(self.N):
            if i in self.frozen_set:
                u_hat[i] = 0
            else:
                u_hat[i] = 0 if llr[i] >= 0 else 1
        return u_hat

    def _metric(self, llr_val, bit):
        """Compute path metric for SCL decoding."""
        return 0 if (bit == (llr_val < 0)) else abs(llr_val)

    def _scl_decode(self, llr):
        """Successive Cancellation List decoding with CRC."""
        paths = [([], 0.0)]
        for i in range(self.N):
            new_paths = []
            for bits, metric in paths:
                if i in self.frozen_set:
                    new_bits = bits + [0]
                    new_metric = metric + self._metric(llr[i], 0)
                    new_paths.append((new_bits, new_metric))
                else:
                    for bit in [0, 1]:
                        ext_bits = bits + [bit]
                        ext_metric = metric + self._metric(llr[i], bit)
                        new_paths.append((ext_bits, ext_metric))
            new_paths.sort(key=lambda x: x[1])
            paths = new_paths[:self.list_size]

        info_indices = list(self.info_set)
        if self.crc_poly:
            for bits, metric in paths:
                if len(bits) == self.N:
                    info_bits = np.array([bits[i] for i in info_indices], dtype=int)
                    if self.crc_check(info_bits):
                        return info_bits
            logging.warning("No CRC-valid candidate found; using lowest-metric path.")

        if paths:
            best_bits = paths[0][0]
            if len(best_bits) == self.N:
                return np.array([best_bits[i] for i in info_indices], dtype=int)
            else:
                logging.error(f"Best path length mismatch: Expected {self.N}, got {len(best_bits)}")
                return np.zeros(len(info_indices), dtype=int)
        else:
            logging.error("SCL decoder finished with no valid paths.")
            return np.zeros(len(info_indices), dtype=int)
###########################################################################







###############################################################################
# latest Performance comparison
def performance_comparison(
        rnn_trainer,
        polar_code_gen,
        snr_range,
        channel_type,
        list_sizes,
        num_trials,
    ):
    device = next(rnn_trainer.model.parameters()).device
    num_info_bits = polar_code_gen.KwCRC  # Must use total info+CRC for error computation!
    rnn_results = {'BER_RNN': [], 'BLER_RNN': []}
    sc_results = {'BER_SC': [], 'BLER_SC': []}
    scl_results = {L: [] for L in list_sizes}

    for snr_db in snr_range:
        # === Generate new data for THIS SNR ===
        X_eval, y_eval = prepare_polar_dataset(
            polar_code_gen, num_samples=num_trials, snr_db=snr_db, channel_type=channel_type
        )
        X_tensor = torch.FloatTensor(X_eval).to(device)
        y_tensor = torch.FloatTensor(y_eval).to(device)

        # --- RNN Decoder ---
        ber_rnn, bler_rnn = rnn_trainer.evaluate(X_tensor, y_tensor)

        rnn_results['BER_RNN'].append(ber_rnn)
        rnn_results['BLER_RNN'].append(bler_rnn)

        # --- SC Decoder (list_size=1) ---
        sc_decoder = PolarCodeDecoder(
        N=BLOCK_LENGTH,
        K=num_info_bits,  # Should be .KwCRC
        list_size=1,
        crc_poly=crc_poly,
        info_set=polar_code_gen.info_set,
        frozen_set=polar_code_gen.frozen_set
        )
#And for SCL:
       # sc_decoder = PolarCodeDecoder(polar_code_gen.N, num_info_bits, list_size=1, crc_poly=polar_code_gen.crc_poly)
        bit_errors, blk_errors = 0, 0
        for i in range(num_trials):
            llr = X_eval[i]          # <--- This LLR was generated at THIS SNR
            true_bits = y_eval[i]
            decoded_bits = sc_decoder.decode(llr)
            bit_errors += np.sum(decoded_bits != true_bits)
            blk_errors += int(np.any(decoded_bits != true_bits))
        sc_results['BER_SC'].append(bit_errors / (num_trials * num_info_bits))
        sc_results['BLER_SC'].append(blk_errors / num_trials)

        # --- SCL Decoders ---
        for L in list_sizes:
            scl_decoder = PolarCodeDecoder(
            N=BLOCK_LENGTH,
            K=num_info_bits,
            list_size=L,
            crc_poly=crc_poly,
            info_set=polar_code_gen.info_set,
            frozen_set=polar_code_gen.frozen_set
            )
          #  scl_decoder = PolarCodeDecoder(polar_code_gen.N, num_info_bits, list_size=L, crc_poly=polar_code_gen.crc_poly)
            bit_errors, blk_errors = 0, 0
            for i in range(num_trials):
                llr = X_eval[i]
                true_bits = y_eval[i]
                decoded_bits = scl_decoder.decode(llr)
                bit_errors += np.sum(decoded_bits != true_bits)
                blk_errors += int(np.any(decoded_bits != true_bits))
            scl_results[L].append({'BER': bit_errors / (num_trials * num_info_bits), 'BLER': blk_errors / num_trials})

    return rnn_results, scl_results, sc_results
########################################################################




############################################################################
#part 6 Plotting fuctions

def plot_ber_bler_comparison(snr_range, rnn_results, scl_results, sc_results, list_sizes):
    plt.figure(figsize=(18, 6))

    # BER Plot
    plt.subplot(1, 2, 1)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, rnn_results['BER_RNN'], label='RNN')
    for size in list_sizes:
        plt.plot(snr_range, [result['BER'] for result in scl_results[size]], label=f'SCL, List Size {size}')
    plt.plot(snr_range, sc_results['BER_SC'], label='SC')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BER')
    plt.title('Bit Error Rate (BER)')
    plt.legend()
    plt.grid(True, which="both", ls="--")

    # BLER Plot
    plt.subplot(1, 2, 2)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, rnn_results['BLER_RNN'], label='RNN')
    for size in list_sizes:
        plt.plot(snr_range, [result['BLER'] for result in scl_results[size]], label=f'SCL, List Size {size}')
    plt.plot(snr_range, sc_results['BLER_SC'], label='SC')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BLER')
    plt.title('Block Error Rate (BLER)')
    plt.legend()
    plt.grid(True, which="both", ls="--")

    plt.tight_layout()
    plt.show()





# for RNN and SCL


def plot_rnn_ber_bler(snr_range, rnn_results):
    plt.figure(figsize=(12, 5))

    # BER Plot
    plt.subplot(1, 2, 1)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, rnn_results['BER_RNN'], marker='o', label='RNN BER')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BER')
    plt.title('RNN Bit Error Rate')
    plt.legend()
    plt.grid(True, which="both", ls="--")
    ax = plt.gca()
    ax.yaxis.set_major_formatter(LogFormatterMathtext())

    # BLER Plot
    plt.subplot(1, 2, 2)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, rnn_results['BLER_RNN'], marker='o', label='RNN BLER')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BLER')
    plt.title('RNN Block Error Rate')
    plt.legend()
    plt.grid(True, which="both", ls="--")
    ax = plt.gca()
    ax.yaxis.set_major_formatter(LogFormatterMathtext())

    plt.tight_layout()
    plt.show()
#2. SCL: Specialized BER/BLER Plot (for a single list size at a time)


def plot_sc_ber_bler(snr_range, sc_results):
    plt.figure(figsize=(12, 5))

    # BER Plot
    plt.subplot(1, 2, 1)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, sc_results['BER_SC'], marker='s', label='SC BER')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BER')
    plt.title('SC Bit Error Rate')
    plt.legend()
    plt.grid(True, which="both", ls="--")
    ax = plt.gca()
    ax.yaxis.set_major_formatter(LogFormatterMathtext())

    # BLER Plot
    plt.subplot(1, 2, 2)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, sc_results['BLER_SC'], marker='s', label='SC BLER')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BLER')
    plt.title('SC Block Error Rate')
    plt.legend()
    plt.grid(True, which="both", ls="--")
    ax = plt.gca()
    ax.yaxis.set_major_formatter(LogFormatterMathtext())

    plt.tight_layout()
    plt.show()

#SCL Plotting Function (ALL list sizes in ONE figure)

def plot_scl_ber_bler(snr_range, scl_results, list_sizes):
    plt.figure(figsize=(12, 5))

    # BER Plot
    plt.subplot(1, 2, 1)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    for L in list_sizes:
        ber_list = [res['BER'] for res in scl_results[L]]
        plt.plot(snr_range, ber_list, marker='^', label=f'SCL L={L}')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BER')
    plt.title('SCL Bit Error Rate (All List Sizes)')
    plt.legend()
    plt.grid(True, which="both", ls="--")
    ax = plt.gca()
    ax.yaxis.set_major_formatter(LogFormatterMathtext())

    # BLER Plot
    plt.subplot(1, 2, 2)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    for L in list_sizes:
        bler_list = [res['BLER'] for res in scl_results[L]]
        plt.plot(snr_range, bler_list, marker='^', label=f'SCL L={L}')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BLER')
    plt.title('SCL Block Error Rate (All List Sizes)')
    plt.legend()
    plt.grid(True, which="both", ls="--")
    ax = plt.gca()
    ax.yaxis.set_major_formatter(LogFormatterMathtext())

    plt.tight_layout()
    plt.show()


######################################################################
def plot_training_validation(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss')
    if val_losses:
        plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()


def plot_confusion_matrix(y_true, y_pred, title='Confusion Matrix'):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(title)
    plt.show()

def plot_ber_bler_comparison(snr_range, rnn_results, scl_results, sc_results, list_sizes):
    plt.figure(figsize=(18, 6))

    # BER Plot
    plt.subplot(1, 2, 1)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, rnn_results['BER_RNN'], label='RNN')
    for size in list_sizes:
        plt.plot(snr_range, [result['BER'] for result in scl_results[size]], label=f'SCL, List Size {size}')
    plt.plot(snr_range, sc_results['BER_SC'], label='SC')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BER')
    plt.title('Bit Error Rate (BER)')
    plt.legend()
    plt.grid(True, which="both", ls="--")

    # BLER Plot
    plt.subplot(1, 2, 2)
    plt.yscale('log')
    plt.ylim(1e-4, 1)
    plt.plot(snr_range, rnn_results['BLER_RNN'], label='RNN')
    for size in list_sizes:
        plt.plot(snr_range, [result['BLER'] for result in scl_results[size]], label=f'SCL, List Size {size}')
    plt.plot(snr_range, sc_results['BLER_SC'], label='SC')
    plt.xlabel('SNR (dB)')
    plt.ylabel('BLER')
    plt.title('Block Error Rate (BLER)')
    plt.legend()
    plt.grid(True, which="both", ls="--")

    plt.tight_layout()
    plt.show()
#Part 7: Main Function
###############################################################################















#part 7 is the last main() function
###############################################################################


#########################################################################################

def main():
    try:
        # --- Config ---
        BLOCK_LENGTH = 128
        INFO_BITS = 64
        crc_poly = [1, 0, 0, 0, 1, 0, 0, 1]
        LEARNING_RATE = 1e-3
        EPOCHS = 50
        BATCH_SIZE = 64
        NUM_SAMPLES = 50000
        NUM_SAMPLES_TRAIN = 50000
        NUM_TRIALS_PERF = 200
        SNR_RANGE_AWGN = np.linspace(0, 5, 11)
        LIST_SIZES = [1, 8, 16]
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # --- Codec Generator ---
        polar_code_gen = PolarCodeGenerator(N=BLOCK_LENGTH, K=INFO_BITS, crc_poly=crc_poly)
        KwCRC = polar_code_gen.KwCRC
        info_set = polar_code_gen.info_set
        frozen_set = polar_code_gen.frozen_set

        print("KwCRC =", KwCRC)
        print("info_set[:10] =", info_set[:10])
        print("frozen_set[:10] =", frozen_set[:10])
        print("CRC poly:", crc_poly)

        # --- Prepare dataset for RNN training ---
        X_raw, y_raw = prepare_polar_dataset(polar_code_gen, NUM_SAMPLES_TRAIN, snr_db=2.5)
        X_tensor = torch.FloatTensor(X_raw).to(device)
        y_tensor = torch.FloatTensor(y_raw).to(device)
        train_size = int(0.8 * X_tensor.shape[0])
        train_X = X_tensor[:train_size]
        train_y = y_tensor[:train_size]
        val_X = X_tensor[train_size:]
        val_y = y_tensor[train_size:]

        # --- RNN Model/Trainer ---
        rnn_model = EnhancedRNNDecoder(BLOCK_LENGTH, KwCRC).to(device)
        rnn_trainer = DecoderTrainer(rnn_model, LEARNING_RATE)

        # --- Train the RNN ---
        train_losses, val_losses = rnn_trainer.train(
            train_X, train_y,
            val_X=val_X, val_y=val_y,
            epochs=EPOCHS, batch_size=BATCH_SIZE,
            generator=polar_code_gen
        )

        # --- SNR BER/BLER Sweep and Plotting ---
        rnn_results = {'BER_RNN': [], 'BLER_RNN': []}
        sc_results = {'BER_SC': [], 'BLER_SC': []}
        scl_results = {L: [] for L in LIST_SIZES}

        for snr_db in SNR_RANGE_AWGN:
            X_eval, y_eval = prepare_polar_dataset(polar_code_gen, NUM_TRIALS_PERF, snr_db=snr_db)
            X_tensor_eval = torch.FloatTensor(X_eval).to(device)
            y_tensor_eval = torch.FloatTensor(y_eval).to(device)

            # --- RNN Eval ---
            ber_rnn, bler_rnn = rnn_trainer.evaluate(X_tensor_eval, y_tensor_eval)
            print(f"RNN evaluation: BER={ber_rnn:.6f}, BLER={bler_rnn:.6f}")
            print(f"Eval batch input shape: {X_tensor_eval.shape}, label shape: {y_tensor_eval.shape}")
            rnn_results['BER_RNN'].append(ber_rnn)
            rnn_results['BLER_RNN'].append(bler_rnn)

            # --- SC Eval ---
            sc_decoder = PolarCodeDecoder(
                BLOCK_LENGTH, KwCRC, list_size=1, crc_poly=crc_poly,
                info_set=info_set, frozen_set=frozen_set
            )
            bit_errors, blk_errors = 0, 0
            for i in range(NUM_TRIALS_PERF):
                llr = X_eval[i]
                true_bits = y_eval[i]
                decoded_bits = sc_decoder.decode(llr)
                bit_errors += np.sum(decoded_bits != true_bits)
                blk_errors += int(np.any(decoded_bits != true_bits))
            sc_results['BER_SC'].append(bit_errors / (NUM_TRIALS_PERF * KwCRC))
            sc_results['BLER_SC'].append(blk_errors / NUM_TRIALS_PERF)

            # --- SCL Eval ---
            for L in LIST_SIZES:
                scl_decoder = PolarCodeDecoder(
                    BLOCK_LENGTH, KwCRC, list_size=L, crc_poly=crc_poly,
                    info_set=info_set, frozen_set=frozen_set
                )
                scl_decoder.crc_fail_count = 0
                bit_errors, blk_errors = 0, 0
                for i in range(NUM_TRIALS_PERF):
                    llr = X_eval[i]
                    true_bits = y_eval[i]
                    decoded_bits = scl_decoder.decode(llr)
                    bit_errors += np.sum(decoded_bits != true_bits)
                    blk_errors += int(np.any(decoded_bits != true_bits))
                scl_results[L].append({'BER': bit_errors / (NUM_TRIALS_PERF * KwCRC), 'BLER': blk_errors / NUM_TRIALS_PERF})

        # --- Plots ---
        plot_training_validation(train_losses, val_losses)
        plot_rnn_ber_bler(SNR_RANGE_AWGN, rnn_results)
        plot_sc_ber_bler(SNR_RANGE_AWGN, sc_results)
        plot_scl_ber_bler(SNR_RANGE_AWGN, scl_results, LIST_SIZES)
        plot_ber_bler_comparison(SNR_RANGE_AWGN, rnn_results, scl_results, sc_results, LIST_SIZES)

        # --- Confusion Matrix ---
        with torch.no_grad():
            rnn_output_prob_example = rnn_model(val_X).cpu().numpy()
            rnn_output_example = (rnn_output_prob_example > 0.5).astype(int)
            y_true_example = val_y.cpu().numpy()

        plot_confusion_matrix(
            y_true_example.flatten(),
            rnn_output_example.flatten(),
            title="RNN Confusion Matrix"
        )

    except Exception as e:
        print(f"Simulation Error: {e}")
        traceback.print_exc()

if __name__ == "__main__":
    main()


#########################################################################################
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1665, LLR[0]=-0.6569
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1466, LLR[0]=-4.5240
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4884, LLR[0]=1.9269
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2716, LLR[0]=1.0715
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5488, LLR[0]=6.1110
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3030, LLR[0]=5.1411
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2563, LLR[0]=4.9568
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0606, LLR[0]=0.2392
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5589, LLR[0]=6.1508
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6423, LLR[0]=2.5343
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8778, LLR[0]=3.4634
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5253, LLR[0]=-6.0180
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4251, LLR[0]=1.6772
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7651, LLR[0]=-3.0186
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4786, LLR[0]=1.8884
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3102, LLR[0]=1.2241
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1547, LLR[0]=-4.5559
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0452, LLR[0]=-4.1237
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0434, LLR[0]=-8.0623
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1555, LLR[0]=-0.6137
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.5367, LLR[0]=-10.0085
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0233, LLR[0]=0.0919
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7281, LLR[0]=2.8728
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.4058, LLR[0]=9.4921
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2791, LLR[0]=-5.0466
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8423, LLR[0]=3.3232
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2851, LLR[0]=-5.0704
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3418, LLR[0]=1.3485
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2001, LLR[0]=-0.7895
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0919, LLR[0]=0.3626
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1706, LLR[0]=-4.6187
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3128, LLR[0]=-5.1799
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4146, LLR[0]=-5.5815
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4816, LLR[0]=-1.9001
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8331, LLR[0]=3.2870
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3343, LLR[0]=1.3192
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.8378, LLR[0]=-11.1968
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9322, LLR[0]=7.6238
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3064, LLR[0]=-1.2088
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3260, LLR[0]=5.2316
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5233, LLR[0]=6.0102
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9208, LLR[0]=-3.6330
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1632, LLR[0]=4.5895
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5403, LLR[0]=2.1316
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3275, LLR[0]=5.2377
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3422, LLR[0]=1.3503
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8284, LLR[0]=-7.2142
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7988, LLR[0]=-3.1519
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7018, LLR[0]=6.7147
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8745, LLR[0]=7.3961
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3870, LLR[0]=-5.4726
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1812, LLR[0]=-4.6605
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9062, LLR[0]=-3.5756
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0014, LLR[0]=7.8967
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1475, LLR[0]=4.5276
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7039, LLR[0]=-2.7773
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.5202, LLR[0]=9.9438
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1505, LLR[0]=4.5395
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0320, LLR[0]=-8.0174
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8444, LLR[0]=7.2774
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2588, LLR[0]=-4.9668
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3269, LLR[0]=1.2898
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2305, LLR[0]=0.9095
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0728, LLR[0]=4.2328
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2465, LLR[0]=0.9725
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0500, LLR[0]=-4.1428
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4245, LLR[0]=-1.6750
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8534, LLR[0]=-3.3671
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0475, LLR[0]=-8.0784
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8762, LLR[0]=-3.4570
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1699, LLR[0]=-4.6158
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2932, LLR[0]=-5.1024
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1607, LLR[0]=4.5796
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1893, LLR[0]=0.7469
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9734, LLR[0]=7.7862
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0420, LLR[0]=-8.0567
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0810, LLR[0]=-8.2107
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2033, LLR[0]=4.7478
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8441, LLR[0]=3.3304
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4751, LLR[0]=1.8746
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4563, LLR[0]=-5.7458
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9798, LLR[0]=7.8113
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2895, LLR[0]=-5.0878
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9996, LLR[0]=-3.9439
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9308, LLR[0]=3.6724
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6871, LLR[0]=6.6566
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9072, LLR[0]=3.5794
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5816, LLR[0]=6.2404
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7113, LLR[0]=2.8065
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7510, LLR[0]=-6.9086
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1889, LLR[0]=0.7451
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1780, LLR[0]=4.6478
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5148, LLR[0]=5.9766
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8376, LLR[0]=7.2503
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.2123, LLR[0]=-8.7288
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2676, LLR[0]=5.0015
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9608, LLR[0]=3.7910
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5107, LLR[0]=-5.9606
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4797, LLR[0]=-1.8925
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4498, LLR[0]=-1.7747
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6634, LLR[0]=2.6175
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4446, LLR[0]=1.7542
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3065, LLR[0]=5.1548
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5749, LLR[0]=2.2683
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3133, LLR[0]=1.2361
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5819, LLR[0]=2.2960
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6460, LLR[0]=2.5490
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6378, LLR[0]=2.5163
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5257, LLR[0]=6.0198
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.9952, LLR[0]=-7.8721
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1801, LLR[0]=0.7105
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2695, LLR[0]=5.0090
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8783, LLR[0]=-3.4655
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3330, LLR[0]=5.2595
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3135, LLR[0]=-1.2368
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.2432, LLR[0]=8.8506
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.5199, LLR[0]=9.9426
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3874, LLR[0]=-1.5286
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2418, LLR[0]=-0.9542
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9338, LLR[0]=-3.6844
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5254, LLR[0]=-2.0732
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1242, LLR[0]=-4.4356
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3758, LLR[0]=1.4828
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5573, LLR[0]=2.1988
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1735, LLR[0]=-4.6300
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0261, LLR[0]=4.0486
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4313, LLR[0]=-5.6472
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2123, LLR[0]=4.7834
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7057, LLR[0]=-2.7843
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=3.0659, LLR[0]=12.0966
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5197, LLR[0]=2.0505
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1380, LLR[0]=-0.5446
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9633, LLR[0]=7.7463
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9593, LLR[0]=-3.7851
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1431, LLR[0]=-4.5100
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=3.2046, LLR[0]=12.6439
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7070, LLR[0]=-2.7895
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0668, LLR[0]=4.2090
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1480, LLR[0]=0.5840
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.1541, LLR[0]=8.4992
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3798, LLR[0]=-1.4987
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8091, LLR[0]=-3.1923
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6179, LLR[0]=6.3837
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4035, LLR[0]=1.5922
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8187, LLR[0]=3.2303
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0092, LLR[0]=3.9817
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5924, LLR[0]=6.2831
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7715, LLR[0]=-3.0440
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3892, LLR[0]=-1.5355
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8734, LLR[0]=-3.4460
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6635, LLR[0]=-2.6180
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0017, LLR[0]=-3.9522
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2262, LLR[0]=4.8382
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8082, LLR[0]=3.1889
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1197, LLR[0]=4.4179
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5887, LLR[0]=-2.3229
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0868, LLR[0]=4.2879
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6799, LLR[0]=2.6827
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6357, LLR[0]=6.4536
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2403, LLR[0]=4.8937
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6869, LLR[0]=2.7103
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5458, LLR[0]=-6.0992
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3583, LLR[0]=-1.4137
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5240, LLR[0]=6.0129
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3457, LLR[0]=-5.3094
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6207, LLR[0]=2.4491
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3072, LLR[0]=5.1577
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.6896, LLR[0]=-10.6118
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9447, LLR[0]=-3.7272
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7621, LLR[0]=6.9524
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2114, LLR[0]=4.7798
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1712, LLR[0]=0.6754
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8287, LLR[0]=-7.2151
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7644, LLR[0]=3.0160
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2042, LLR[0]=-0.8056
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8444, LLR[0]=-7.2773
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3703, LLR[0]=1.4611
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2555, LLR[0]=-4.9538
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5152, LLR[0]=2.0327
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4679, LLR[0]=-1.8460
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2444, LLR[0]=4.9099
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5413, LLR[0]=6.0812
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2993, LLR[0]=-1.1809
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0191, LLR[0]=-0.0753
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1920, LLR[0]=0.7575
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7874, LLR[0]=7.0523
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0326, LLR[0]=-0.1287
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9580, LLR[0]=-3.7798
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5408, LLR[0]=2.1336
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5376, LLR[0]=2.1213
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5792, LLR[0]=-6.2309
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4026, LLR[0]=-1.5883
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2638, LLR[0]=-1.0410
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4299, LLR[0]=1.6963
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1143, LLR[0]=-0.4510
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6904, LLR[0]=-6.6697
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0427, LLR[0]=-0.1684
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5965, LLR[0]=2.3536
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.3776, LLR[0]=-9.3809
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5853, LLR[0]=2.3092
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6560, LLR[0]=2.5884
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4760, LLR[0]=5.8237
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6506, LLR[0]=6.5126
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2826, LLR[0]=-5.0605
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7479, LLR[0]=-6.8966
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5501, LLR[0]=-2.1704
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4480, LLR[0]=1.7675
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0140, LLR[0]=4.0008
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2547, LLR[0]=-1.0051
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9063, LLR[0]=3.5758
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7539, LLR[0]=-2.9744
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1918, LLR[0]=0.7568
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3693, LLR[0]=-1.4572
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7733, LLR[0]=-3.0512
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1261, LLR[0]=-4.4430
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0719, LLR[0]=4.2291
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2878, LLR[0]=-5.0812
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3880, LLR[0]=5.4763
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4679, LLR[0]=1.8461
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2911, LLR[0]=-1.1485
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4514, LLR[0]=1.7808
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1383, LLR[0]=4.4912
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2273, LLR[0]=0.8969
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1232, LLR[0]=-4.4316
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5244, LLR[0]=6.0146
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8087, LLR[0]=3.1908
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7880, LLR[0]=7.0547
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.1993, LLR[0]=-8.6773
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0843, LLR[0]=4.2782
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1976, LLR[0]=-0.7796
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0303, LLR[0]=0.1194
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3978, LLR[0]=1.5694
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7021, LLR[0]=-2.7704
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8779, LLR[0]=-3.4636
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3869, LLR[0]=-5.4722
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9247, LLR[0]=-3.6483
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6557, LLR[0]=2.5870
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4949, LLR[0]=1.9528
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7968, LLR[0]=-3.1437
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4850, LLR[0]=1.9136
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.4145, LLR[0]=9.5266
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8142, LLR[0]=-7.1579
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7588, LLR[0]=-6.9394
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3545, LLR[0]=5.3442
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1856, LLR[0]=4.6778
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7221, LLR[0]=6.7946
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3195, LLR[0]=5.2063
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3619, LLR[0]=5.3735
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1335, LLR[0]=-4.4721
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3860, LLR[0]=-5.4685
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6894, LLR[0]=-2.7201
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3577, LLR[0]=1.4114
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6687, LLR[0]=-2.6386
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2724, LLR[0]=-5.0202
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7041, LLR[0]=2.7781
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9055, LLR[0]=-3.5727
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6260, LLR[0]=-2.4699
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6805, LLR[0]=2.6851
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8080, LLR[0]=-3.1880
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2401, LLR[0]=0.9473
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2084, LLR[0]=4.7677
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.3114, LLR[0]=9.1199
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8202, LLR[0]=-3.2362
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3818, LLR[0]=-5.4519
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8845, LLR[0]=-3.4900
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4805, LLR[0]=-1.8958
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9294, LLR[0]=3.6670
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2454, LLR[0]=0.9682
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3583, LLR[0]=-1.4135
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.2769, LLR[0]=8.9835
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9760, LLR[0]=3.8508
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1131, LLR[0]=4.3918
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1483, LLR[0]=4.5308
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3870, LLR[0]=-1.5268
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2609, LLR[0]=1.0293
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4567, LLR[0]=5.7475
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8563, LLR[0]=-7.3241
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2224, LLR[0]=0.8774
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5706, LLR[0]=-2.2514
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2964, LLR[0]=1.1695
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0603, LLR[0]=8.1291
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6944, LLR[0]=-2.7396
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7817, LLR[0]=-3.0843
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7373, LLR[0]=-6.8548
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2021, LLR[0]=0.7973
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8639, LLR[0]=-7.3542
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7445, LLR[0]=2.9374
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7433, LLR[0]=-6.8782
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4406, LLR[0]=1.7386
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1537, LLR[0]=-4.5521
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3724, LLR[0]=1.4692
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1437, LLR[0]=-0.5671
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9724, LLR[0]=3.8365
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3416, LLR[0]=-1.3477
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1750, LLR[0]=4.6359
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8555, LLR[0]=7.3209
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1432, LLR[0]=0.5652
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7273, LLR[0]=-6.8152
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.4633, LLR[0]=-9.7189
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2922, LLR[0]=1.1530
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0718, LLR[0]=8.1744
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3614, LLR[0]=-1.4259
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1048, LLR[0]=-0.4134
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2797, LLR[0]=5.0491
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3808, LLR[0]=1.5025
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0160, LLR[0]=-0.0633
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5732, LLR[0]=6.2072
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6645, LLR[0]=2.6217
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8927, LLR[0]=-3.5222
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.3794, LLR[0]=9.3881
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2308, LLR[0]=4.8563
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5603, LLR[0]=-6.1561
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3094, LLR[0]=1.2207
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9368, LLR[0]=7.6418
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6330, LLR[0]=-6.4430
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9083, LLR[0]=7.5292
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5677, LLR[0]=6.1854
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5292, LLR[0]=2.0880
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.6212, LLR[0]=10.3421
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5014, LLR[0]=-1.9783
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0018, LLR[0]=0.0069
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7425, LLR[0]=-2.9298
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0485, LLR[0]=4.1368
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8404, LLR[0]=-3.3160
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1808, LLR[0]=4.6589
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1760, LLR[0]=-0.6944
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3495, LLR[0]=-5.3244
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6226, LLR[0]=2.4564
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0028, LLR[0]=3.9567
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7439, LLR[0]=6.8807
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8353, LLR[0]=3.2957
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.2448, LLR[0]=-8.8569
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0533, LLR[0]=0.2103
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9436, LLR[0]=3.7232
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8457, LLR[0]=3.3366
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2232, LLR[0]=-0.8806
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3399, LLR[0]=-5.2865
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6415, LLR[0]=2.5312
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0655, LLR[0]=8.1495
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5907, LLR[0]=-6.2761
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1317, LLR[0]=-4.4651
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5201, LLR[0]=-2.0520
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3178, LLR[0]=-1.2539
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3863, LLR[0]=-1.5242
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9275, LLR[0]=7.6049
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-3.2545, LLR[0]=-12.8410
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1109, LLR[0]=4.3831
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0024, LLR[0]=3.9551
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6582, LLR[0]=-2.5970
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0938, LLR[0]=4.3158
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7818, LLR[0]=3.0845
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5933, LLR[0]=6.2865
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2917, LLR[0]=1.1509
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9898, LLR[0]=-3.9054
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0591, LLR[0]=-4.1789
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1069, LLR[0]=-0.4216
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5162, LLR[0]=-2.0365
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8656, LLR[0]=-3.4155
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6728, LLR[0]=-2.6546
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1498, LLR[0]=0.5911
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1797, LLR[0]=-0.7092
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5625, LLR[0]=-6.1648
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3296, LLR[0]=-1.3004
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3386, LLR[0]=1.3361
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8125, LLR[0]=-3.2057
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5674, LLR[0]=2.2389
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9632, LLR[0]=-3.8002
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5777, LLR[0]=-6.2251
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2557, LLR[0]=-4.9544
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6101, LLR[0]=-6.3528
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0855, LLR[0]=4.2829
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4835, LLR[0]=5.8531
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0404, LLR[0]=4.1049
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1380, LLR[0]=0.5446
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2619, LLR[0]=1.0332
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3642, LLR[0]=-1.4368
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9738, LLR[0]=7.7878
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7557, LLR[0]=6.9274
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0620, LLR[0]=8.1358
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5128, LLR[0]=-5.9689
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1399, LLR[0]=0.5519
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7001, LLR[0]=2.7624
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3511, LLR[0]=1.3852
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5932, LLR[0]=2.3407
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1836, LLR[0]=4.6701
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.6222, LLR[0]=-10.3458
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3612, LLR[0]=-5.3708
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.1923, LLR[0]=-8.6500
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1957, LLR[0]=4.7179
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0910, LLR[0]=0.3589
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7779, LLR[0]=-7.0149
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3308, LLR[0]=5.2509
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3692, LLR[0]=1.4568
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8956, LLR[0]=-7.4793
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4900, LLR[0]=-5.8791
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2228, LLR[0]=4.8248
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3169, LLR[0]=-5.1959
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1949, LLR[0]=4.7144
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9255, LLR[0]=-3.6516
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0323, LLR[0]=-8.0184
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5445, LLR[0]=-6.0939
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2832, LLR[0]=5.0630
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6245, LLR[0]=2.4640
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2023, LLR[0]=4.7439
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3493, LLR[0]=-5.3236
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6496, LLR[0]=-2.5632
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5598, LLR[0]=6.1544
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0677, LLR[0]=-4.2126
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.1241, LLR[0]=-8.3807
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5554, LLR[0]=6.1368
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4261, LLR[0]=5.6267
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7593, LLR[0]=2.9958
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2093, LLR[0]=-0.8257
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3704, LLR[0]=1.4615
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0518, LLR[0]=8.0954
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3864, LLR[0]=-1.5245
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8501, LLR[0]=-3.3540
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0936, LLR[0]=-0.3692
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1822, LLR[0]=0.7188
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3487, LLR[0]=-1.3757
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6242, LLR[0]=-2.4629
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0136, LLR[0]=-7.9446
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3999, LLR[0]=-1.5778
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7164, LLR[0]=2.8267
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4009, LLR[0]=-5.5273
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2532, LLR[0]=-4.9447
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7580, LLR[0]=2.9906
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3972, LLR[0]=-1.5670
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3537, LLR[0]=1.3955
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2806, LLR[0]=-5.0525
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7228, LLR[0]=-6.7976
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5178, LLR[0]=5.9886
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5335, LLR[0]=-2.1051
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3592, LLR[0]=5.3626
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.3483, LLR[0]=-9.2654
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0663, LLR[0]=-4.2070
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2349, LLR[0]=4.8724
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6131, LLR[0]=-6.3646
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7708, LLR[0]=3.0413
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2464, LLR[0]=-0.9721
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7269, LLR[0]=2.8679
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7014, LLR[0]=2.7674
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1743, LLR[0]=4.6335
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2193, LLR[0]=-4.8110
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1331, LLR[0]=0.5253
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5914, LLR[0]=6.2791
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6011, LLR[0]=-6.3174
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4716, LLR[0]=5.8064
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5097, LLR[0]=-5.9565
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5611, LLR[0]=6.1596
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2334, LLR[0]=-4.8666
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0579, LLR[0]=-8.1194
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3768, LLR[0]=5.4323
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7930, LLR[0]=7.0746
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3752, LLR[0]=1.4805
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5815, LLR[0]=6.2400
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9840, LLR[0]=3.8824
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0329, LLR[0]=4.0752
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5474, LLR[0]=6.1053
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7117, LLR[0]=-2.8081
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2906, LLR[0]=-1.1467
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5528, LLR[0]=2.1809
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.1368, LLR[0]=8.4310
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4269, LLR[0]=5.6298
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6409, LLR[0]=6.4744
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7764, LLR[0]=-3.0634
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2732, LLR[0]=-1.0780
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1604, LLR[0]=-0.6329
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2056, LLR[0]=4.7568
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5253, LLR[0]=-2.0726
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7375, LLR[0]=-2.9100
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4501, LLR[0]=-5.7216
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9595, LLR[0]=3.7857
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.2120, LLR[0]=-8.7274
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6745, LLR[0]=-2.6613
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8068, LLR[0]=-3.1834
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8013, LLR[0]=7.1072
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4294, LLR[0]=5.6396
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4037, LLR[0]=5.5385
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2765, LLR[0]=-1.0910
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2741, LLR[0]=1.0817
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2075, LLR[0]=-0.8186
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7507, LLR[0]=2.9620
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1089, LLR[0]=-0.4296
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8099, LLR[0]=3.1954
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7522, LLR[0]=2.9679
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.0898, LLR[0]=-8.2455
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1485, LLR[0]=-4.5316
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4482, LLR[0]=-1.7684
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5050, LLR[0]=-5.9380
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7445, LLR[0]=-2.9375
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.2322, LLR[0]=-8.8074
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8025, LLR[0]=3.1664
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4660, LLR[0]=-5.7841
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3141, LLR[0]=5.1849
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8459, LLR[0]=3.3376
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7241, LLR[0]=-2.8569
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6850, LLR[0]=6.6484
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.1357, LLR[0]=-8.4266
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6509, LLR[0]=6.5137
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3998, LLR[0]=1.5774
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7609, LLR[0]=3.0023
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5185, LLR[0]=2.0457
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0109, LLR[0]=3.9884
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0710, LLR[0]=8.1712
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4429, LLR[0]=1.7473
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6891, LLR[0]=-2.7189
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6340, LLR[0]=2.5015
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7115, LLR[0]=2.8071
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2530, LLR[0]=0.9981
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5566, LLR[0]=2.1961
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2019, LLR[0]=0.7964
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7290, LLR[0]=-2.8762
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3700, LLR[0]=1.4599
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6277, LLR[0]=-6.4224
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0169, LLR[0]=7.9576
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7595, LLR[0]=2.9965
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1219, LLR[0]=4.4266
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1117, LLR[0]=-4.3864
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9386, LLR[0]=3.7033
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1322, LLR[0]=4.4673
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8529, LLR[0]=7.3107
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.8487, LLR[0]=7.2941
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6177, LLR[0]=-2.4371
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1814, LLR[0]=0.7156
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.5594, LLR[0]=-2.2073
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2775, LLR[0]=-5.0403
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.0272, LLR[0]=7.9983
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9883, LLR[0]=-3.8995
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8376, LLR[0]=3.3047
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4023, LLR[0]=-1.5871
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9883, LLR[0]=3.8992
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2845, LLR[0]=-1.1226
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.2331, LLR[0]=8.8107
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6185, LLR[0]=6.3860
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6047, LLR[0]=6.3315
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.9725, LLR[0]=-7.7827
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4600, LLR[0]=1.8151
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0067, LLR[0]=3.9719
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2877, LLR[0]=-1.1351
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1288, LLR[0]=-4.4539
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5273, LLR[0]=-6.0260
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0102, LLR[0]=3.9860
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5856, LLR[0]=6.2559
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3858, LLR[0]=5.4679
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0899, LLR[0]=0.3549
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0895, LLR[0]=-4.2986
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8643, LLR[0]=3.4103
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1660, LLR[0]=-4.6006
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1802, LLR[0]=4.6565
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.9637, LLR[0]=3.8024
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.3449, LLR[0]=9.2520
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7982, LLR[0]=-7.0951
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6873, LLR[0]=-2.7118
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.4085, LLR[0]=9.5029
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1800, LLR[0]=-0.7103
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5759, LLR[0]=-6.2177
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0266, LLR[0]=-0.1050
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3531, LLR[0]=1.3931
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9184, LLR[0]=-3.6237
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4642, LLR[0]=-1.8315
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5776, LLR[0]=6.2247
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1136, LLR[0]=-4.3936
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7275, LLR[0]=-2.8705
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.3672, LLR[0]=-1.4489
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1773, LLR[0]=4.6450
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1929, LLR[0]=-0.7612
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.6784, LLR[0]=-6.6221
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=2.2779, LLR[0]=8.9875
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1005, LLR[0]=4.3420
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.0888, LLR[0]=-4.2959
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.9022, LLR[0]=-7.5052
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7653, LLR[0]=6.9650
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2658, LLR[0]=-4.9941
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.3047, LLR[0]=-5.1480
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8589, LLR[0]=3.3887
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4715, LLR[0]=1.8605
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2566, LLR[0]=1.0124
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7115, LLR[0]=-2.8073
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1856, LLR[0]=4.6777
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.4867, LLR[0]=-1.9204
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.8048, LLR[0]=-7.1208
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3806, LLR[0]=1.5016
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6234, LLR[0]=6.4054
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1221, LLR[0]=-4.4274
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.2467, LLR[0]=-0.9735
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4718, LLR[0]=-5.8072
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.4210, LLR[0]=1.6609
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7730, LLR[0]=-3.0500
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9846, LLR[0]=-3.8849
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.7705, LLR[0]=3.0402
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.2959, LLR[0]=5.1130
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5818, LLR[0]=2.2956
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1740, LLR[0]=-0.6864
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8993, LLR[0]=3.5483
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7705, LLR[0]=-3.0400
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.4929, LLR[0]=-5.8902
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.3441, LLR[0]=5.3031
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.7597, LLR[0]=-6.9430
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2116, LLR[0]=0.8351
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.8637, LLR[0]=3.4079
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.0254, LLR[0]=4.0457
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.3165, LLR[0]=1.2488
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.5938, LLR[0]=2.3428
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1192, LLR[0]=4.4158
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.9801, LLR[0]=7.8125
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.6016, LLR[0]=6.3191
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.7697, LLR[0]=-3.0368
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.7802, LLR[0]=7.0239
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.1388, LLR[0]=-4.4934
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0859, LLR[0]=-0.3390
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.2780, LLR[0]=1.0970
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6268, LLR[0]=-2.4732
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.6493, LLR[0]=-2.5618
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.2371, LLR[0]=-4.8809
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.1956, LLR[0]=-8.6629
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.0386, LLR[0]=0.1525
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6356, LLR[0]=2.5079
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.5557, LLR[0]=6.1381
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.1086, LLR[0]=0.4286
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-1.5667, LLR[0]=-6.1817
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.1020, LLR[0]=4.3480
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9146, LLR[0]=-3.6084
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-2.2020, LLR[0]=-8.6880
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.1434, LLR[0]=-0.5657
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6292, LLR[0]=2.4824
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=0.6973, LLR[0]=2.7512
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.9743, LLR[0]=-3.8441
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.8670, LLR[0]=-3.4207
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=1.4518, LLR[0]=5.7283
# DEBUG SNR=2.5: noise_var=0.5069, example received[0]=-0.0900, LLR[0]=-0.3550
# ...
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
# WARNING:root:No CRC-valid candidate found; using lowest-metric path.
